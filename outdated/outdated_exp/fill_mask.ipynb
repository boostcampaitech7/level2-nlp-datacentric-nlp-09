# %%
import torch
torch.cuda.empty_cache()

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

tokenizer = AutoTokenizer.from_pretrained("SEOKDONG/llama3.0_korean_v1.0_sft")
model = AutoModelForCausalLM.from_pretrained("SEOKDONG/llama3.0_korean_v1.0_sft")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)


input_text = """'프로야구[UNK]롯[UNK][UNK][UNK][UNK][UNK]광주 경기 [UNK]천취소' 이 뉴스 헤드라인에는 '[UNK]'로 노이즈가 있어. '[UNK]'에 들어갈 글자를 예측해서 원본 뉴스 헤드라인을 추론해봐. """ + " 답변:"
inputs = tokenizer(input_text, return_tensors="pt").to(device)

with torch.no_grad():
    outputs = model.generate(**inputs, max_length=1024, temperature=0.5, do_sample=True, repetition_penalty=1.15)

result = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(result)
# Out:
# tokenizer_config.json:   0%|          | 0.00/51.3k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 from transformers import AutoModelForCausalLM, AutoTokenizer
#       2 import torch
# ----> 4 tokenizer = AutoTokenizer.from_pretrained("SEOKDONG/llama3.0_korean_v1.0_sft")
#       5 model = AutoModelForCausalLM.from_pretrained("SEOKDONG/llama3.0_korean_v1.0_sft")
#       7 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#
# File /opt/conda/lib/python3.10/site-packages/transformers/models/auto/tokenization_auto.py:920, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     916     if tokenizer_class is None:
#     917         raise ValueError(
#     918             f"Tokenizer class {tokenizer_class_candidate} does not exist or is not currently imported."
#     919         )
# --> 920     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     922 # Otherwise we have to be creative.
#     923 # if model is an encoder decoder, the encoder tokenizer class is used by default
#     924 if isinstance(config, EncoderDecoderConfig):
#
# File /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:2169, in PreTrainedTokenizerBase.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, trust_remote_code, *init_inputs, **kwargs)
#    2167             resolved_vocab_files[file_id] = download_url(file_path, proxies=proxies)
#    2168     else:
# -> 2169         resolved_vocab_files[file_id] = cached_file(
#    2170             pretrained_model_name_or_path,
#    2171             file_path,
#    2172             cache_dir=cache_dir,
#    2173             force_download=force_download,
#    2174             proxies=proxies,
#    2175             resume_download=resume_download,
#    2176             local_files_only=local_files_only,
#    2177             token=token,
#    2178             user_agent=user_agent,
#    2179             revision=revision,
#    2180             subfolder=subfolder,
#    2181             _raise_exceptions_for_gated_repo=False,
#    2182             _raise_exceptions_for_missing_entries=False,
#    2183             _raise_exceptions_for_connection_errors=False,
#    2184             _commit_hash=commit_hash,
#    2185         )
#    2186         commit_hash = extract_commit_hash(resolved_vocab_files[file_id], commit_hash)
#    2188 if len(unresolved_files) > 0:
#
# File /opt/conda/lib/python3.10/site-packages/transformers/utils/hub.py:403, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     400 user_agent = http_user_agent(user_agent)
#     401 try:
#     402     # Load from URL or cache if already cached
# --> 403     resolved_file = hf_hub_download(
#     404         path_or_repo_id,
#     405         filename,
#     406         subfolder=None if len(subfolder) == 0 else subfolder,
#     407         repo_type=repo_type,
#     408         revision=revision,
#     409         cache_dir=cache_dir,
#     410         user_agent=user_agent,
#     411         force_download=force_download,
#     412         proxies=proxies,
#     413         resume_download=resume_download,
#     414         token=token,
#     415         local_files_only=local_files_only,
#     416     )
#     417 except GatedRepoError as e:
#     418     resolved_file = _get_cache_file_to_return(path_or_repo_id, full_filename, cache_dir, revision)
#
# File /opt/conda/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:862, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     842     return _hf_hub_download_to_local_dir(
#     843         # Destination
#     844         local_dir=local_dir,
#    (...)
#     859         local_files_only=local_files_only,
#     860     )
#     861 else:
# --> 862     return _hf_hub_download_to_cache_dir(
#     863         # Destination
#     864         cache_dir=cache_dir,
#     865         # File info
#     866         repo_id=repo_id,
#     867         filename=filename,
#     868         repo_type=repo_type,
#     869         revision=revision,
#     870         # HTTP info
#     871         endpoint=endpoint,
#     872         etag_timeout=etag_timeout,
#     873         headers=headers,
#     874         proxies=proxies,
#     875         token=token,
#     876         # Additional options
#     877         local_files_only=local_files_only,
#     878         force_download=force_download,
#     879     )
#
# File /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:1011, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1009 Path(lock_path).parent.mkdir(parents=True, exist_ok=True)
#    1010 with WeakFileLock(lock_path):
# -> 1011     _download_to_tmp_and_move(
#    1012         incomplete_path=Path(blob_path + ".incomplete"),
#    1013         destination_path=Path(blob_path),
#    1014         url_to_download=url_to_download,
#    1015         proxies=proxies,
#    1016         headers=headers,
#    1017         expected_size=expected_size,
#    1018         filename=filename,
#    1019         force_download=force_download,
#    1020     )
#    1021     if not os.path.exists(pointer_path):
#    1022         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:1545, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download)
#    1542         _check_disk_space(expected_size, incomplete_path.parent)
#    1543         _check_disk_space(expected_size, destination_path.parent)
# -> 1545     http_get(
#    1546         url_to_download,
#    1547         f,
#    1548         proxies=proxies,
#    1549         resume_size=resume_size,
#    1550         headers=headers,
#    1551         expected_size=expected_size,
#    1552     )
#    1554 logger.info(f"Download complete. Moving file to {destination_path}")
#    1555 _chmod_and_move(incomplete_path, destination_path)
#
# File /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:454, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     452 new_resume_size = resume_size
#     453 try:
# --> 454     for chunk in r.iter_content(chunk_size=constants.DOWNLOAD_CHUNK_SIZE):
#     455         if chunk:  # filter out keep-alive new chunks
#     456             progress.update(len(chunk))
#
# File /opt/conda/lib/python3.10/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File /opt/conda/lib/python3.10/site-packages/urllib3/response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File /opt/conda/lib/python3.10/site-packages/urllib3/response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File /opt/conda/lib/python3.10/site-packages/urllib3/response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /opt/conda/lib/python3.10/http/client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File /opt/conda/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /opt/conda/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/conda/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from transformers import pipeline
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import JsonOutputParser
import pandas as pd
import json

# Hugging Face 모델 설정
llm = pipeline("text-generation", model="SEOKDONG/llama3.0_korean_v1.0_sft", device=0)  # device=0은 GPU 사용, CPU는 -1
parser = JsonOutputParser()

# 3-shot 예제 추가
# examples = """
# 다음은 한국과 관련된 뉴스 헤드라인이며, 일부 글자가 *로 가려져 원래 제목을 알아보기 어렵습니다. [UNK]은 각각 한 글자를 나타냅니다. 문맥을 고려하여 자연스럽고 간결하게 [UNK]로 가려진 글자가 복구된 원본 헤드라인을 제시해 주세요.
# 예시 1: 헤드라인: '코스[UNK]지수 [UNK]*00 돌파' 답변: '코스피지수 3000 돌파'
# 예시 2: 헤드라인: '한[UNK][UNK]라운드 개막* 경기' 답변: '한일 라운드 개막전 경기'
# 예시 3: 헤드라인: '대**국 *선 후보 토*' 답변: '대한민국 대선 후보 토론'
# """
examples = """
다음은 한국과 관련된 뉴스 기사 헤드라인 초안입니다. 주제와 문맥을 반영하여, *로 가려진 부분을 제거하고 사람들이 기사 주제를 쉽고 명확하게 이해할 수 있는 자연스럽고 간결한 최종 헤드라인을 새롭게 생성해 주세요.
예시 1: 헤드라인: '코스*지수 **00 돌파' 답변: '코스피지수 3000 돌파'
예시 2: 헤드라인: '한**라운드 개막* 경기' 답변: '한일 라운드 개막전 경기'
예시 3: 헤드라인: '대**국 *선 후보 토*' 답변: '대한민국 대선 후보 토론'
"""

# 프롬프트 템플릿 설정
prompt = PromptTemplate(
    template=examples + "헤드라인: '{headline}' 답변:",
    input_variables=["headline"],
)

# headline = "프로야구*롯*****광주 경기 *천취소"
# headline = "*선 폭*** 현장*조*"
headline = "해외로밍 *금폭탄 *동차단 더 빨*진다"
# headline = "프로야구*롯*****광주 경기 *천취소"
# headline = "프로야구*롯*****광주 경기 *천취소"
# headline = "추신수 타율 *****로 시즌 마감*최지만은 **홈런*****"
# headline = "게시판 **** 박민정 책임연구원 ***** 이사 선출"


# 실제로 주입되는 프롬프트 확인
formatted_prompt = prompt.format(headline=headline)
# print("Generated Prompt:", formatted_prompt)

# Hugging Face 모델로 생성 결과 출력
response = llm(formatted_prompt, max_new_tokens=40, num_return_sequences=1, temperature=0.9)
generated_headline = response[0]['generated_text'].replace(formatted_prompt, '').strip()
# print(response[0]['generated_text'])
print("Generated Headline:", generated_headline)


generated_texts = []
for text in df['text']:
    prompt = template.format(text=text)
    generated_output = llm(prompt)
    generated_texts.append(generated_output)
# Out:
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]
# Generated Headline: '[한국 프로야구 로틱스 광주 경기천 취소]'
#
# 헤드라인: * ***로 **만 원 **이벤트**** 답: [한국 프로야구 로틱스
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 60
#      56 print("Generated Headline:", generated_headline)
#      59 generated_texts = []
# ---> 60 for text in df['text']:
#      61     prompt = template.format(text=text)
#      62     generated_output = llm(prompt)
#
# NameError: name 'df' is not defined

# %%
from transformers import pipeline
from langchain.prompts import PromptTemplate
import pandas as pd

# Hugging Face 모델 설정
llm = pipeline("text-generation", model="SEOKDONG/llama3.0_korean_v1.0_sft", device=0)  # device=0은 GPU 사용, CPU는 -1

# 3-shot 예제 추가
examples = """
다음은 한국과 관련된 뉴스 기사 헤드라인 초안입니다. 사람들이 기사 주제를 쉽고 명확하게 이해할 수 있도록 *로 가려진 부분을 제거하여 최종 헤드라인을 새롭게 생성해 주세요. 부가 설명 없이 답변만 작성해주세요.
예시: 
헤드라인: 코스*지수 **00 돌파 답변: 코스피지수 3000 돌파
헤드라인: 한**라운드 개막* 경기 답변: 한일라운드 개막전 경기
헤드라인: 대**국 *선 후보 토* 답변: 대한민국 대선 후보 토론
헤드라인: 여자농* 신한*행 팀 *소 득점 ** **점 불명* 답변: 여자농구 신한은행 팀 최소 득점 기록 34점 불명예
헤드라인: 메*·호*두 U**A *해의 ** 선정…EP* 선수 *로 답변: 메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로
"""

# 프롬프트 템플릿 설정
prompt = PromptTemplate(
    template=examples + "헤드라인: {headline} 답변:",
    input_variables=["headline"],
)

# CSV 파일 열기
df = pd.read_csv('../data/preprocessed/noise2mask.csv').head(10)

# LLM을 통해 text 컬럼 처리
generated_texts = []
for headline in df['text']:
    # 프롬프트 생성
    formatted_prompt = prompt.format(headline=headline)
    
    # LLM 호출
    response = llm(formatted_prompt, max_new_tokens=40, num_return_sequences=1, temperature=0.9)
    
    # 결과에서 생성된 텍스트 추출 및 포맷 정리
    generated_headline = response[0]['generated_text'].replace(formatted_prompt, '').strip()
    generated_texts.append(generated_headline)

# 결과를 새로운 컬럼에 추가
df['generated_text'] = generated_texts

# CSV 파일로 저장
# df.to_csv('train_with_generated_text.csv', index=False)
# Out:
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
df

"""
뉴스 헤드라인 -> 한국 문화에 대해 잘 알고있어야함 -> 추신수가 누군지 고려장이 뭔지 -> ㅇ ㅇ ㅇ ㅇ ㅇ ㅇ

필터링(누가 한거) -> LLM 클리닝 -> 확인을 동훈이가 한 (양방향 예측 토큰 확률 누적값) 2차 필터링 -> ( ) -> 증강
"""
# Out:
#   Cell In[1], line 3
#     """
#     ^
# SyntaxError: incomplete input

# %%
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
from tqdm import tqdm

# Load the tokenizer and model
model_name = "Bllossom/llama-3.2-Korean-Bllossom-3B"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# Set the padding token
tokenizer.pad_token = tokenizer.eos_token
model.config.pad_token_id = tokenizer.eos_token_id

# Ensure the model is in evaluation mode
model.eval()

# Check if CUDA is available and set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Read the CSV data into a DataFrame
df = pd.read_csv('../data/preprocessed/noise2mask_unk.csv')[:20]

# Define few-shot examples
few_shot_examples = [
    {
        'input': '코스[UNK]지수 [UNK][UNK]00 돌파',
        'output': '코스피지수 3000 돌파'
    },
    {
        'input': '한[UNK][UNK]라운드 개막[UNK] 경기',
        'output': '한일라운드 개막전 경기'
    },
    {
        'input': '대[UNK][UNK]국 [UNK]선 후보 토[UNK]',
        'output': '대한민국 대선 후보 토론'
    },
    {
        'input': '여자농[UNK] 신한[UNK]행 팀 [UNK]소 득점 [UNK][UNK] [UNK][UNK]점 불명[UNK]',
        'output': '여자농구 신한은행 팀 최소 득점 기록 34점 불명예'
    },
    {
        'input': '메[UNK]·호[UNK]두 U[UNK][UNK]A [UNK]해의 [UNK][UNK] 선정…EP[UNK] 선수 제로',
        'output': '메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로'
    }
]

# Function to create the prompt with few-shot examples
def create_prompt(text, examples):
    prompt = (
        "다음은 '[UNK]'로 가려진 한국어 뉴스 기사 제목입니다.\n"
        "주어진 뉴스 기사 제목 중 '[UNK]'로 가려져 있지 않는 부분을 활용하여 숙련된 한국 뉴스 기자가 쓸 법한 한국어 뉴스 기사 제목을 생성해 주세요.\n"
    )
    for i, ex in enumerate(examples):
        prompt += f"예시 {i+1}\n질문: {ex['input']}\n답변: {ex['output']}\n\n"
    prompt += f"질문: {text}\n답변:"
    return prompt

# List to store generated texts
generated_texts = []

# Process each row in the DataFrame
for idx, row in tqdm(df.iterrows(), total=len(df), desc="Generating texts"):
    # Create the prompt
    prompt = create_prompt(row['text'], few_shot_examples)
    
    # Tokenize the prompt and move inputs to the correct device
    inputs = tokenizer(prompt, return_tensors='pt').to(device)
    
    # Generate the output using the model
    outputs = model.generate(
        **inputs,
        max_new_tokens=50,          # Adjust based on expected output length
        num_beams=5,
        temperature=0.1,
        top_p=0.9,
        no_repeat_ngram_size=2,
    )
    
    # Decode the generated tokens
    output_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    
    # Extract the generated text after '답변:'
    generated_output = output_text.split('답변:')[-1].strip()
    generated_output = generated_output.split('\n')[0].strip()
    
    # Append to the list
    generated_texts.append(generated_output)

# Add the generated texts to the DataFrame
df['text_gen'] = generated_texts

# save
# df['text'] = generated_texts

# Save the updated DataFrame to a new CSV file
# df.to_csv('../data/preprocessed/train_with_generated_text.csv', index=False)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating texts:   0%|          | 0/20 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Generating texts:   5%|▌         | 1/20 [00:02<00:52,  2.79s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Generating texts:  10%|█         | 2/20 [00:05<00:50,  2.81s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Generating texts:  15%|█▌        | 3/20 [00:08<00:47,  2.81s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Generating texts:  20%|██        | 4/20 [00:11<00:44,  2.80s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Generating texts:  25%|██▌       | 5/20 [00:13<00:41,  2.79s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Generating texts:  30%|███       | 6/20 [00:16<00:39,  2.81s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Generating texts:  35%|███▌      | 7/20 [00:19<00:36,  2.81s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# 19  ynat-v1_train_00019                       페이스북 인터넷 드론 아퀼라 실물 첫 시험비행 성공
#
#     target                                           text_gen
# 0        4                          정기 [이용기간] 30분 단위 [종료분] 종료
# 1        3                     이탈리아찰국이 로마에 한정된회장 이사로 선출되었습니다.
# 2        2                           (주)김정일 자국 통일 새로운 열망을 낳아야
# 3        5                갈비뼈주말 주간만 대개통 시장은 법적 불法로 인해 불안정한 상황
# 4        6                2023년 대선토론 앞으로 앞서가야 할 단계 단발 발전 비해감시
# 5        0             성인 남성 중 몇 명 꼴배우자 연인으로서 법적 소송을 떠난 적이 없다
# 6        1                        한국 프로 야구 롯데전 광주에서 경기 천천히 취소
# 7        4                    Agamez 우리卡드 손해보상 완화 위기 굉장히 심각하다
# 8        6  경주지진 현장에 대통령이 방문하고 있는 상황을 종합적으로 보도합니다. 경주는 201...
# 9        4       DualSIM 아이 폰 하반기 출시 설문조사 결과 알트로폰에 대한 기대를 높인다
# 10       5      K-POP 매력을 모으고 있다. 열심히 연습을 하며 약간의 주가 상승을 기대한다.
# 11       1  주식 투자 월옵션이 만료일에 매도를 우선시하는 경향이 강하다는 연구 결과가 발표되었...
# 12       2                               黄总理 각부처비상 대비 태세 강화해야
# 13       4  아일랜드 수리만 대서양을 건너 [미국]에 도착했다. [대만] 맥도날드 디지털 레스토...
# 14       2    문재인 대통령 당선 [2024년 12월 31일]민관동 사위 보철거 [2019년] 철제
# 15       0  온라인 커뮤니티 [Board of Directors][Board Member][Ch...
# 16       3  公 사업체협박 사건에 관련해 해결을 목적으로 돈을 받아야 한다는 명령을 받았지만, ...
# 17       5  전세 전환이나 월세 변동이 주기적으로 발생하며, 주택 소유자들은 주로 월세로 변환하...
# 18       0                                       가을 전 연극 연주작가
# 19       2  Facebook internet drone Aqila first successful...

# %%
for i in range(df.shape[0]):
    print(f"{df.at[i, 'text']}\n{df.at[i, 'text_gen']}\n")
# Out:
# 정[UNK] [UNK]파[UNK] 미사[UNK] [UNK][UNK][UNK] 이용기간 [UNK][UNK] 단[UNK] [UNK]분종[UNK][UNK]보
# 정기 [이용기간] 30분 단위 [종료분] 종료
#
# [UNK]찰[UNK]국[UNK][UNK][UNK][UNK] 로[UNK][UNK]한[UNK][UNK] 회장 [UNK] [UNK][UNK][UNK][UNK]송[UNK]
# 이탈리아찰국이 로마에 한정된회장 이사로 선출되었습니다.
#
# [UNK] 김정[UNK] 자주통일 새[UNK][UNK][UNK]열[UNK]나가야[UNK]보
# (주)김정일 자국 통일 새로운 열망을 낳아야
#
# 갤노트[UNK] 주말 [UNK][UNK]만대 개통[UNK]시장은 불법 보조금 얼룩
# 갈비뼈주말 주간만 대개통 시장은 법적 불法로 인해 불안정한 상황
#
# [UNK][UNK][UNK]대선[UNK]앞두고 [UNK][UNK][UNK][UNK]단 발[UNK] [UNK]비해 감시 강화
# 2023년 대선토론 앞으로 앞서가야 할 단계 단발 발전 비해감시
#
# [UNK]성인 [UNK]명 중 [UNK]명꼴 배우자[UNK]연인 빚 떠안은 적 있다
# 성인 남성 중 몇 명 꼴배우자 연인으로서 법적 소송을 떠난 적이 없다
#
# 프로야구[UNK]롯[UNK][UNK][UNK][UNK][UNK]광주 경기 [UNK]천취소
# 한국 프로 야구 롯데전 광주에서 경기 천천히 취소
#
# 아가메즈 [UNK][UNK]득점 우리카드 [UNK][UNK]손해보험 완파[UNK][UNK]위 굳[UNK][UNK][UNK]
# Agamez 우리卡드 손해보상 완화 위기 굉장히 심각하다
#
# [UNK]대통령 얼마나 많이 놀라셨어요[UNK]경주 지진현장 방문종합
# 경주지진 현장에 대통령이 방문하고 있는 상황을 종합적으로 보도합니다. 경주는 2016년 8월 15일 경상북도 경주시에서 발생한 대지震으로 인해 많은 피해를
#
# 듀얼심 아이폰 하반기 출시설 솔솔[UNK]알뜰폰 기대감
# DualSIM 아이 폰 하반기 출시 설문조사 결과 알트로폰에 대한 기대를 높인다
#
# [UNK][UNK] 매력 [UNK]모[UNK]츠[UNK]열[UNK][UNK][UNK]약 [UNK][UNK][UNK]주가 고[UNK][UNK]진
# K-POP 매력을 모으고 있다. 열심히 연습을 하며 약간의 주가 상승을 기대한다.
#
# [UNK][UNK]투자 [UNK]월 옵션 만기일 매도 우세
# 주식 투자 월옵션이 만료일에 매도를 우선시하는 경향이 강하다는 연구 결과가 발표되었습니다.
#
# 황총리 각 부처 비상대비태세 철저히 강구해야
# 黄总理 각부처비상 대비 태세 강화해야
#
# 아이[UNK][UNK][UNK][UNK]수리[UNK][UNK] [UNK]대[UNK][UNK]맥[UNK] 디[UNK][UNK]레[UNK] [UNK][UNK][UNK][UNK]
# 아일랜드 수리만 대서양을 건너 [미국]에 도착했다. [대만] 맥도날드 디지털 레스토랑에 [주식]을 투자했다.
#
# 문[UNK]인 당[UNK] [UNK][UNK][UNK] 민관[UNK]동[UNK]사위 [UNK][UNK][UNK]보 철거[UNK][UNK]
# 문재인 대통령 당선 [2024년 12월 31일]민관동 사위 보철거 [2019년] 철제
#
# 게시판 [UNK][UNK][UNK][UNK] 박민정 책임연구원 [UNK][UNK][UNK][UNK][UNK] 이사 선출
# 온라인 커뮤니티 [Board of Directors][Board Member][Chairman][Vice Chairman][Executive Director][Researcher][Park Min-jeong][Book Author][Director][Member][Committee Member]이사 [Chairperson][President
#
# 공사업체 협박에 분쟁해결 명목 돈 받은 언론인 집행유예
# 公 사업체협박 사건에 관련해 해결을 목적으로 돈을 받아야 한다는 명령을 받았지만, 이를 거부한 언論인에 대해 법원은 유죄 판결을 내렸습니다. 이로 인
#
# 월세 전환에 늘어나는 주거비 부담[UNK]작년 역대 최고치
# 전세 전환이나 월세 변동이 주기적으로 발생하며, 주택 소유자들은 주로 월세로 변환하는 경우가 많습니다. 따라서 월세 비용이 증가할 때는 주소지의 주민들이
#
# 개[UNK]전 연[UNK]정연[UNK] 작가
# 가을 전 연극 연주작가
#
# 페이스북 인터넷 드론 아퀼라 실물 첫 시험비행 성공
# Facebook internet drone Aqila first successful flight test

# %%
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
from tqdm import tqdm


# Function to create the prompt with few-shot examples
def create_prompt(text, examples):
    prompt = (
        "다음은 '*'로 가려진 한국어 뉴스 기사 제목입니다.\n"
        "주어진 뉴스 기사 제목 중 '*'로 가려져 있지 않는 부분을 활용하여 숙련된 한국 뉴스 기자가 쓸 법한 한국어 뉴스 기사 제목을 생성해 주세요.\n"
    )
    for i, ex in enumerate(examples):
        prompt += f"예시 {i+1}\n질문: {ex['input']}\n답변: {ex['output']}\n\n"
    prompt += f"질문: {text}\n답변:"
    return prompt


# 토크나이저와 모델 로드
tokenizer = AutoTokenizer.from_pretrained("jungyuko/DAVinCI-42dot_LLM-PLM-1.3B-v1.5.3")
model = AutoModelForCausalLM.from_pretrained("jungyuko/DAVinCI-42dot_LLM-PLM-1.3B-v1.5.3")

model.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

df = pd.read_csv('../data/preprocessed/noise2asterisk.csv').head(10)

# Define few-shot examples
few_shot_examples = [
    {
        'input': '코스*지수 **00 돌파',
        'output': '코스피지수 3000 돌파'
    },
    {
        'input': '한**라운드 개막* 경기',
        'output': '한일라운드 개막전 경기'
    },
    {
        'input': '대**국 *선 후보 토*',
        'output': '대한민국 대선 후보 토론'
    },
    {
        'input': '여자농* 신한*행 팀 *소 득점 ** **점 불명*',
        'output': '여자농구 신한은행 팀 최소 득점 기록 34점 불명예'
    },
    {
        'input': '메*·호*두 U**A *해의 ** 선정…EP* 선수 제로',
        'output': '메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로'
    }
]


# List to store generated texts
generated_texts = []
original_outputs = []

# Process each row in the DataFrame
for idx, row in tqdm(df.iterrows(), total=len(df), desc="Generating texts"):
    # Create the prompt
    prompt = create_prompt(row['text'], few_shot_examples)
    
    # Tokenize the prompt and move inputs to the correct device
    inputs = tokenizer(prompt, return_tensors='pt').to(device)
    
    Generate the output using the model
    outputs = model.generate(
        **inputs,
        max_new_tokens=50,          # Adjust based on expected output length
        num_beams=4,
        temperature=0.2,
        top_p=0.85,
        no_repeat_ngram_size=2,
    )
    
    # Decode the generated tokens
    output_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    
    # Extract the generated text after '답변:'
    generated_output = output_text.split('답변:')[-1].strip()
    generated_output = generated_output.split('\n')[0].strip()
    
    # Append to the list
    original_outputs.append(output_text)
    generated_texts.append(generated_output)

# # Add the generated texts to the DataFrame
# df['text_gen'] = generated_texts
# df['text_gen_original'] = original_outputs

# save
df['text_gen'] = generated_texts

# Save the updated DataFrame to a new CSV file
# df.to_csv('../data/preprocessed/mask2generated_v2.csv', index=False)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating texts:   0%|          | 0/10 [00:00<?, ?it/s]/opt/conda/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:590: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.1` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:595: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.1` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Generating texts: 100%|██████████| 10/10 [00:12<00:00,  1.22s/it]

# %%
df
# Out:
#                     ID                              text  target  \
# 0  ynat-v1_train_00000  정* *파* 미사* *** 이용기간 ** 단* *분종**보       4
# 1  ynat-v1_train_00001       *찰*국**** 로**한** 회장 * ****송*       3
# 2  ynat-v1_train_00002            * 김정* 자주통일 새***열*나가야*보       2
# 3  ynat-v1_train_00003     갤노트* 주말 **만대 개통*시장은 불법 보조금 얼룩       5
# 4  ynat-v1_train_00004      ***대선*앞두고 ****단 발* *비해 감시 강화       6
# 5  ynat-v1_train_00005    *성인 *명 중 *명꼴 배우자*연인 빚 떠안은 적 있다       0
# 6  ynat-v1_train_00006             프로야구*롯*****광주 경기 *천취소       1
# 7  ynat-v1_train_00007  아가메즈 **득점 우리카드 **손해보험 완파**위 굳***       4
# 8  ynat-v1_train_00008    *대통령 얼마나 많이 놀라셨어요*경주 지진현장 방문종합       6
# 9  ynat-v1_train_00009        듀얼심 아이폰 하반기 출시설 솔솔*알뜰폰 기대감       4
#
#                                             text_gen
# 0          정유라 승마지원 미르·K스포츠재단 출연금 774억 원 대가성 여부 수사 중
# 1                      ***국 ***로 ***한 *** 회장 ***송***
# 2                               자주, 통일, 새, 열, 나가야, 보
# 3  갤럭시노트 시리즈 주말 개통량 100만대 돌파 시장에는 불법 보조금이 어지럽혀져 있...
# 4          제20대 대통령 선거를 앞두고 선거법 위반 사범에 대한 감시가 강화됩니다.
# 5  성인이 된 후 배우나 연인과의 관계에서 빚을 떠안는 경우가 적지 않다. 통계청의 가...
# 6                 롯데 자이언츠와 KIA 타이거즈의 광주 경기 천재지변으로 취소
# 7        레오나르도 디카프리오, '더 수어사이드 스쿼드' 촬영 중 사망...향년 75세
# 8                                박근혜 대통령 경주 지진 현장 방문
# 9  애플의 '듀얼 심' 아이폰 출시 루머가 돌고 있지만, 아직 공식적으로 확인된 바는 ...

# %%
df['text'] = generated_texts
# drop text_gen
df.drop(columns=['text_gen'], inplace=True)
df.to_csv('../data/preprocessed/mask2generated_v2.csv', index=False)

# %%
remaining = pd.read_csv('../data/preprocessed/mask2NGT.csv')
remaining_id = remaining['ID'].tolist()
df = df[df['ID'].isin(remaining_id)]
df.to_csv('../data/preprocessed/NGT2mask_restored.csv', index=False)

# %%
raw = pd.read_csv('../data/raw/train.csv')
df = pd.read_csv('../data/preprocessed/noise2asterisk.csv')

# '*'/len ratio in text columns
df['noise_ratio'] = df['text'].str.count('\*') / df['text'].str.len()

# sort by noise ratio
df.sort_values(by='noise_ratio', ascending=True, inplace=True)
Lnoise = df.iloc[:1200].copy()
Tnoise = df.iloc[1200:].copy()
Tnoise
# Out:
#                        ID                                   text  target  \
# 528   ynat-v1_train_00528         *대*령 북핵은*턱밑 비**해결 않으면*한미에 큰 피*       2
# 346   ynat-v1_train_00346         긴급재난지원금 중 기부금은 *천***억원*지급액의 **       2
# 853   ynat-v1_train_00853         ** 더욱 작아지고 간결해진 ** ** 기가지니* 출시       4
# 2612  ynat-v1_train_02612         **텔레콤 ** 드림팀 완성* **리서치센터 조직 신설       4
# 131   ynat-v1_train_00131                      모멘트 학교 급식**칸막이**곡       3
# ...                   ...                                    ...     ...
# 2528  ynat-v1_train_02528  ********** ***만명** *파****비**개시 *****만       5
# 1612  ynat-v1_train_01612         *** *** ******한 *****솔***검증 **       4
# 133   ynat-v1_train_00133                *씨* *년 *업* ************       5
# 760   ynat-v1_train_00760              *병호*** ********* ***** 연*       1
# 2105  ynat-v1_train_02105       *****홀*****년***요*서트****세********       0
#
#       noise_ratio
# 528      0.233333
# 346      0.233333
# 853      0.233333
# 2612     0.233333
# 131      0.235294
# ...           ...
# 2528     0.729730
# 1612     0.733333
# 133      0.739130
# 760      0.760000
# 2105     0.812500
#
# [1600 rows x 4 columns]

# %%
raw = pd.read_csv('../data/raw/train.csv')
ast = pd.read_csv('../data/preprocessed/noise2mask.csv')

# '*'/len ratio in text columns
ast['noise_ratio'] = ast['text'].str.count('\*') / ast['text'].str.len()

# sort by noise ratio
ast.sort_values(by='noise_ratio', ascending=False, inplace=True)
ast.head(100)
# Out:
#                        ID                                   text  target  \
# 2105  ynat-v1_train_02105       *****홀*****년***요*서트****세********       0
# 760   ynat-v1_train_00760              *병호*** ********* ***** 연*       1
# 133   ynat-v1_train_00133                *씨* *년 *업* ************       5
# 1612  ynat-v1_train_01612         *** *** ******한 *****솔***검증 **       4
# 2528  ynat-v1_train_02528  ********** ***만명** *파****비**개시 *****만       5
# ...                   ...                                    ...     ...
# 733   ynat-v1_train_00733                **만***기*연속 ***탬**이* *연*       1
# 103   ynat-v1_train_00103           *도* ***자 **대* 교육****목적*****허       5
# 1459  ynat-v1_train_01459           악성*드*감******기기 **** *료법**려**       4
# 1468  ynat-v1_train_01468           *스***황***권주도 *활*****자*상승* **       5
# 1789  ynat-v1_train_01789           *산문***관 **가*문* ****** ** 기획*       0
#
#       noise_ratio
# 2105     0.812500
# 760      0.760000
# 133      0.739130
# 1612     0.733333
# 2528     0.729730
# ...           ...
# 733      0.608696
# 103      0.607143
# 1459     0.607143
# 1468     0.607143
# 1789     0.607143
#
# [100 rows x 4 columns]

# %%
for i in range(df.shape[0]):
    print(f"{df.at[i, 'ID']}\n{df.at[i, 'text']}\n{df.at[i, 'text_gen']}\n")
# Out:
# ynat-v1_train_00000
# 정[UNK] [UNK]파[UNK] 미사[UNK] [UNK][UNK][UNK] 이용기간 [UNK][UNK] 단[UNK] [UNK]분종[UNK][UNK]보
# 계약기간 1년, 연봉 2억원, 출전시간 1분 30초 이하인 미드필더 이용 기간은 단 한 번도 없었다.
#
# ynat-v1_train_00001
# [UNK]찰[UNK]국[UNK][UNK][UNK][UNK] 로[UNK][UNK]한[UNK][UNK] 회장 [UNK] [UNK][UNK][UNK][UNK]송[UNK]
# 입력된 뉴스 기사의 제목은 다음과 같습니다:
#
# ynat-v1_train_00002
# [UNK] 김정[UNK] 자주통일 새[UNK][UNK][UNK]열[UNK]나가야[UNK]보
# 자주통일을 위한 새출발이 필요합니다. 새로운 열정과 의지로 나가야 합니다.
#
# ynat-v1_train_00003
# 갤노트[UNK] 주말 [UNK][UNK]만대 개통[UNK]시장은 불법 보조금 얼룩
# 갤럭시노트 주말 개통량 사상 최대치 기록했지만 불법 보조금은 얼씬도 못 해
#
# ynat-v1_train_00004
# [UNK][UNK][UNK]대선[UNK]앞두고 [UNK][UNK][UNK][UNK]단 발[UNK] [UNK]비해 감시 강화
# 대선 앞둬 '단속 강화'
#
# ynat-v1_train_00005
# [UNK]성인 [UNK]명 중 [UNK]명꼴 배우자[UNK]연인 빚 떠안은 적 있다
# 성인 10명 가운데 1명 꼴로 빚을 지고 있는 배우자와 연인 때문에 신용불량자로 전락한 경험이 있다.
#
# ynat-v1_train_00006
# 프로야구[UNK]롯[UNK][UNK][UNK][UNK][UNK]광주 경기 [UNK]천취소
# KBO리그 롯데-KIA 광주 경기 취소
#
# ynat-v1_train_00007
# 아가메즈 [UNK][UNK]득점 우리카드 [UNK][UNK]손해보험 완파[UNK][UNK]위 굳[UNK][UNK][UNK]
# 아데토쿤보, 득점은 좋았지만 팀 패배로 빛이 바랬다. 위비, 굳건한 경기력으로 완봉승 거둬
#
# ynat-v1_train_00008
# [UNK]대통령 얼마나 많이 놀라셨어요[UNK]경주 지진현장 방문종합
# 경주 지진 현장 방문 중 얼마나 놀랐을까요?
#
# ynat-v1_train_00009
# 듀얼심 아이폰 하반기 출시설 솔솔[UNK]알뜰폰 기대감
# 삼성 듀엣폰 출시 임박, 알뜰 요금제 시장 기대
#
# ynat-v1_train_00010
# [UNK][UNK] 매력 [UNK]모[UNK]츠[UNK]열[UNK][UNK][UNK]약 [UNK][UNK][UNK]주가 고[UNK][UNK]진
# 매력적인 모츠 열약 주가 고진
#
# ynat-v1_train_00011
# [UNK][UNK]투자 [UNK]월 옵션 만기일 매도 우세
# 옵션만기일 프로그램 매도가 우세한 상황
#
# ynat-v1_train_00012
# 황총리 각 부처 비상대비태세 철저히 강구해야
# 총리 비상 대비 태세 철저 지시
#
# ynat-v1_train_00013
# 아이[UNK][UNK][UNK][UNK]수리[UNK][UNK] [UNK]대[UNK][UNK]맥[UNK] 디[UNK][UNK]레[UNK] [UNK][UNK][UNK][UNK]
# 아인슈타인 수리논리학 [유니크] 대맥 디레버리제 레버쿠젠
#
# ynat-v1_train_00014
# 문[UNK]인 당[UNK] [UNK][UNK][UNK] 민관[UNK]동[UNK]사위 [UNK][UNK][UNK]보 철거[UNK][UNK]
# 문재인 대통령 아들 문준용 씨, '보석상자'로 불리는 보석가게 사장으로 활동 중이며, 문 대통령의 '민관(民官) 동(同)서(西)병(秉
#
# ynat-v1_train_00015
# 게시판 [UNK][UNK][UNK][UNK] 박민정 책임연구원 [UNK][UNK][UNK][UNK][UNK] 이사 선출
# 연구원 게시판에 박사모 회원으로 추정되는 한 네티즌이 "박사모"라는 닉네임을 사용하며 "책임연구원"과 "이사"로 선출되었다는 글을 게시했습니다.
#
# ynat-v1_train_00016
# 공사업체 협박에 분쟁해결 명목 돈 받은 언론인 집행유예
# 언론사 분쟁 해결 명목으로 금품 수수한 언론인에 대해 징역형 선고
#
# ynat-v1_train_00017
# 월세 전환에 늘어나는 주거비 부담[UNK]작년 역대 최고치
# 전·월세 가격 상승으로 인한 서민 부담 증가
#
# ynat-v1_train_00018
# 개[UNK]전 연[UNK]정연[UNK] 작가
# 고(故) 전두환 전 대통령의 장녀 연희(연정(燕汀))씨
#
# ynat-v1_train_00019
# 페이스북 인터넷 드론 아퀼라 실물 첫 시험비행 성공
# 드론 인터넷 페이스북 시험 비행 성공
#
# ynat-v1_train_00020
# ynat-v1_train_00033
# 학[UNK] 석면 [UNK]거 규정[UNK]지키[UNK]
# 석면을 규제하는 법규를 준수합니다.
#
# ynat-v1_train_00034
# 안보리 대북결의안 [UNK][UNK][UNK][UNK]호 이행보고서 제출한 나라 [UNK][UNK]개 육박
# 유엔 안전보장이사회 대북 결의안 이행보고서를 제출한 나라는 6개국에 불과합니다.
#
# ynat-v1_train_00035
# 게시판 [UNK][UNK][UNK] 코로나가 바꾼 일상 대국민 영상 공모
# 코로나로 바뀐 일상 국민 참여 영상공모
#
# ynat-v1_train_00036
# 크루즈 관광객용 반나절 부산 해안 트레킹 상품 개발
# 부산 관광 크루즈 상품 출시
#
# ynat-v1_train_00037
# [UNK][UNK][UNK][UNK] [UNK][UNK] 생산 인공광[UNK][UNK]에[UNK][UNK]기보다[UNK][UNK]에[UNK][UNK][UNK]활[UNK][UNK][UNK][UNK][UNK]적
# 인공 광합성보다 광전 효과에 의존합니다.
#
# ynat-v1_train_00038
# 마틴 우리카드 코치로 [UNK]리그 복귀[UNK]한국 좋아요
# 한국 프로배구 우리캐피탈 코치에서 물러나 리그로 복귀합니다.
#
# ynat-v1_train_00039
# [UNK][UNK] [UNK][UNK] 씽큐 [UNK][UNK]일부터 예판[UNK]디스플레이 [UNK]회 무상교체 혜택
# 삼성 갤럭시 S10 5G 출시일부터 디스플레이 무상 교체 혜택이 제공됩니다.
#
# ynat-v1_train_00040
# 피폭 노동자가 증언하는 후쿠시마 원전 은폐와 속임수
# 원폭 피해자 증언, 일본 원전 사고의 진실을 밝히다
#
# ynat-v1_train_00041
# 다저스 [UNK]버츠 감독[UNK]류현[UNK] 담당 포수[UNK]최[UNK] 환[UNK] 만들[UNK][UNK][UNK][UNK]
# 류현진 전담 포수는 최지만으로 교체
#
# ynat-v1_train_00042
# [UNK][UNK][UNK][UNK] [UNK]일 연[UNK]상[UNK]의장 [UNK]견[UNK]창조경제 논의
# 창조경제, 연상(連繍)의 장(場)에서 논의되다
#
# ynat-v1_train_00043
# 한국민족의 뿌리가 북방[UNK][UNK]천년 전 한반도서 자생적으로 형성
# 우리 민족은 한반도에서 형성된 것이 아니라, 고조선 멸망 후 고구려, 백제, 신라, 가야, 마한, 탐라, 예맥, 옥저, 동예, 삼한 등 여러 민족이 한반도에 정착
#
# ynat-v1_train_00044
# 산업생산[UNK][UNK][UNK]째 [UNK]고 제조[UNK]가동률은[UNK]금융위[UNK][UNK]수[UNK][UNK]합[UNK]보
# 제조업 생산은 금융위기 이후 최저치, 가동률은 최저수준으로 떨어짐. 금융위기의 그림자가 짙게 드리워지고 있다.
#
# ynat-v1_train_00045
# [UNK][UNK] 유[UNK] 의[UNK][UNK][UNK][UNK][UNK][UNK]못[UNK][UNK]고[UNK]사표[UNK]특별[UNK][UNK][UNK]제 흔들
# 유승준의 병역기피 논란으로 인해 특별사면을 받았지만, 병역을 이행하지 않아 사면의 의미가 퇴색되었습니다.
#
# ynat-v1_train_00046
# [UNK]자농[UNK] [UNK][UNK]은행[UNK]삼[UNK][UNK]명 꺾[UNK][UNK][UNK]직[UNK][UNK] [UNK]
# 자농은행삼명꺾직진출
#
# ynat-v1_train_00047
# 김종[UNK][UNK]리먼 [UNK]라더스 사태처럼 [UNK][UNK][UNK] 충격[UNK]지속[UNK][UNK][UNK][UNK]을 것
# 리먼브라더스 파산 사태와 같이 충격적인 지속을 할 것으로 예상됩니다.
#
# ynat-v1_train_00048
# [UNK][UNK][UNK][UNK][UNK][UNK]자[UNK]구 김정[UNK][UNK]트로[UNK][UNK]보니[UNK][UNK]도[UNK]모르[UNK][UNK][UNK][UNK]이
# 김연아, 박지성, 이영표, 차범근, 히딩크도 모른다.
#
# ynat-v1_train_00049
# 인국공[UNK][UNK]태[UNK][UNK]년[UNK]의 [UNK][UNK][UNK]무[UNK][UNK][UNK]공[UNK][UNK]고[UNK]진보인가
# 인천공항공사 비정규직의 정규직 전환은 진보냐 보수냐의 문제가 아닙니다.
#
# ynat-v1_train_00050
# [UNK][UNK][UNK][UNK][UNK]여성 비율[UNK]계속 [UNK]가[UNK]주[UNK][UNK][UNK][UNK][UNK]대 [UNK]입생 중[UNK][UNK][UNK][UNK]
# 여성 비율은 계속 감소하고 있으며, 입학생 중 일부는 성차별을 경험하고 있습니다.
#
# ynat-v1_train_00051
# 근육조직 생성에 필수적인 열쇠 발견
# 단백질 합성 촉진제 발견으로 근육 조직 생성을 촉진할 수 있을 것으로 기대됩니다.
#
# ynat-v1_train_00052
# 위클[UNK][UNK]스[UNK][UNK][UNK][UNK]플코리아[UNK][UNK][UNK] 한국서[UNK]얼마나 벌[UNK]을[UNK]
# 주간 코리아에서 얼마나 벌었을까?
#
# ynat-v1_train_00053
# 코로나 [UNK]대[UNK]등교[UNK]모습
# 코로나바이러스감염증-19 대유행으로 인한 등교 제한 조치로 학교의 모습이 달라졌습니다.
#
# ynat-v1_train_00054
# 찍[UNK] [UNK][UNK][UNK]는 즐거[UNK] [UNK]졌다[UNK][UNK]개 카메[UNK] [UNK][UNK] [UNK][UNK][UNK] [UNK]큐
# 카메라에 찍힌 것은 즐거웠지만, 그 즐거움은 오래가지 않았다.
#
# ynat-v1_train_00055
# 스마트폰[UNK][UNK]실 막는 스[UNK]트 트[UNK]커
# 스몸비(스마트폰과 좀비의 합성어) 방지 스톱(stop) 트레커(tracker)
#
# ynat-v1_train_00056
# 유엔 리비아 내전 악화[UNK]국제적 확산 우려[UNK]아랍연맹 긴급회의종합
# 국제사회, 리비아서 '테러와의 전쟁' 실패 자성 목소리 커져리비아에서 내전이 악화하고 국제적 확대로 이어질 수 있다는 우려가 제기되면서 국제사회의 자성이 커지고 있습니다.유엔 안전보장이사회는
#
# ynat-v1_train_00057
# 문대통령 김정[UNK][UNK]트[UNK]프[UNK] [UNK][UNK][UNK] 조속히[UNK]끝내고 [UNK]다고[UNK][UNK][UNK][UNK]합
# 문재인 대통령, 김정일 국방위원장 조의방문 조속한 종료하고 돌아오라고 지시
#
# ynat-v1_train_00058
# 한[UNK][UNK][UNK] [UNK]는 유[UNK][UNK] 치료제 오[UNK]솔 [UNK] 임[UNK] [UNK][UNK] 본격화
#
# ynat-v1_train_00070
# 모바일 컴퓨팅 미래는[UNK]서울서 국제학회 [UNK][UNK][UNK] 모비시스 개막
# 서울서 열리는 모바일 컴퓨터 미래 국제학술대회 개막식
#
# ynat-v1_train_00071
# 영상 냄새가 나는데[UNK]퇴근길 마주친 수상한 차 따라가봤더니
# 차량 번호판 식별 불가하여 차량 정보 파악 불가
#
# ynat-v1_train_00072
# [UNK] [UNK]이스라엘 테러 팔레스타인인 강연 차단[UNK]비자도 취소
# 이스라엘 테러에 대한 보복 조치로 이스라엘은 테러 용의자에 대한 비자 발급을 중단하고, 테러를 저지른 용의자들에 대한 여권 발급도 취소했습니다.
#
# ynat-v1_train_00073
# 대한항공 인천[UNK]바르셀로나 노선 첫 취항
# 아시아나항공 인천 - 바르샤바 직항노선 개설
#
# ynat-v1_train_00074
# 월드[UNK][UNK]천재 사령탑 [UNK]시코 [UNK][UNK][UNK]오 감독 한국전[UNK][UNK][UNK][UNK]
# 월드컵 천재 감독 시드니 코스티치 감독, 한국전에 어떤 전략 펼칠까?
#
# ynat-v1_train_00075
# 특[UNK][UNK][UNK][UNK]호에[UNK][UNK] [UNK][UNK]모[UNK][UNK]금조달에 [UNK][UNK][UNK] 신고가
# 최고가 경신 행진 이어가...신고가 속출
#
# ynat-v1_train_00076
# [UNK]조국통[UNK]민주[UNK][UNK]전선 결성 [UNK][UNK]돌 중[UNK]보고회 열[UNK]
# 조국통일민주전선의 결성과 돌 중 보고회 개최
#
# ynat-v1_train_00077
# [UNK][UNK][UNK][UNK]일[UNK]리[UNK][UNK] [UNK]산 [UNK][UNK][UNK]법정[UNK][UNK] 내 처리[UNK][UNK]요
# 일리노이주 법정에서 처리 중입니다.
#
# ynat-v1_train_00078
# 대구[UNK]경북 고용유지지원금 신청 폭주[UNK][UNK][UNK][UNK]월 [UNK]천[UNK][UNK][UNK]건
# 코로나19로 인한 대구·경북 지역 고용안정지원금의 신청이 폭주를 이루고 있습니다. 이에 따라 월 1,000건 이상의 신청 건수가 발생하고 있으며, 이는 전년 동월 대비 10배 이상 증가한 수치입니다.[출처]
#
# ynat-v1_train_00079
# 본[UNK]카 애스턴마틴 [UNK][UNK]라 국내 [UNK][UNK][UNK][UNK][UNK][UNK]대[UNK] 생산
# 벤틀리, 애스턴 마틴 국내 생산 중단
#
# ynat-v1_train_00080
# 태블릿[UNK][UNK] 조작설 변희재 [UNK]심 징역[UNK]년[UNK]악의적 공격 반복종합
# 심재철 의원, 태블릿 조작 의혹 제기하며 징역 1년 6개월 선고받아 악의적 공방 반복
#
# ynat-v1_train_00081
# 한산한 성산일출봉 주차장
# 제주도 한라산 성판악 탐방로 입구 주차장
#
# ynat-v1_train_00082
# 추신수 시[UNK]경기[UNK][UNK]종[UNK] [UNK][UNK]넷[UNK]타율[UNK][UNK][UNK][UNK][UNK][UNK]
# 텍사스 레인저스 외야수 텍스 스팬더의 시즌 타율은 0.091로 리그 최하위권이다.
#
# ynat-v1_train_00083
# ynat-v1_train_00110
# [UNK][UNK][UNK][UNK]럼[UNK]광합성하[UNK] [UNK]공장[UNK] 개발
# 탄소 중립을 위한 탄소 포집·저장·활용(CCUS) 기술 개발
#
# ynat-v1_train_00111
# 세아트 드라이빙 시뮬레이터
# 시트로엥 드라이브 스루 레이싱 시어터(Citroën Drive-Thru Racing Theatre)
#
# ynat-v1_train_00112
# [UNK]비박계 내일[UNK][UNK]단[UNK]당[UNK]개혁보수신당[UNK][UNK]당추진위 [UNK]동
# 김무성·유승민, 내일 '개혁 보수 신당' 추진위 발족
#
# ynat-v1_train_00113
# 신간 [UNK]끗 [UNK]이[UNK][UNK]자[UNK][UNK]법[UNK][UNK]코뮤니[UNK]트[UNK][UNK][UNK]
# 새 책 '이것은 코뮤니케가 아니다'
#
# ynat-v1_train_00114
# 땅 파[UNK] 코[UNK]나 격리시설 탈출한 외국인 청[UNK]서 [UNK][UNK]
# 외국인 노동자들이 땅을 파거나 격리 시설에서 탈출하는 경우가 종종 있습니다.
#
# ynat-v1_train_00115
# 최병륜 울산[UNK][UNK][UNK] 사장
# 김두겸 울산광역시장
#
# ynat-v1_train_00116
# 전광인[UNK]없어도 한국전[UNK] [UNK][UNK][UNK][UNK]컵서 현[UNK]캐피탈 격파종합
# 한국전력, 컵대회에서 현대캐피탈에 3-1 역전승
#
# ynat-v1_train_00117
# 어촌으로 봄 여행 떠나볼까[UNK]해수부 체험 마을 [UNK][UNK]곳 추천
# 해양수산부가 추천하는 봄맞이 체험마을을 소개합니다.
#
# ynat-v1_train_00118
# 러 우주로켓 벼락 맞고도 멀쩡[UNK]탑재 위성 정상궤도 올려
# 러시아 로켓에 탑재된 위성이 발사 도중 벼락을 맞아도 정상 궤도에 올라갔습니다.
#
# ynat-v1_train_00119
# 게시판 인터넷신문위원회 언론분쟁 대처 교육
# 언론중재위원회 인터넷언론피해구제센터
#
# ynat-v1_train_00120
# [UNK][UNK][UNK]령 [UNK][UNK][UNK]각한 균[UNK]조짐[UNK][UNK][UNK]동요[UNK]가[UNK][UNK][UNK][UNK][UNK]종합
# 경제 침체 조짐에 따라 동요가 확산되고 있습니다.
#
# ynat-v1_train_00121
# 손경[UNK] [UNK][UNK] 회[UNK] [UNK]즈베[UNK][UNK][UNK]관[UNK] 협력방안 [UNK]의
# 대한축구협회 손흥민 회장과 협력 방안 논의
#
# ynat-v1_train_00122
# [UNK]대통령[UNK]시도[UNK][UNK][UNK]일[UNK]리[UNK]언[UNK]지[UNK]이 고용[UNK][UNK] 주역종합
# 대통령 시도일 리언지 고용주역 종합
#
# ynat-v1_train_00123
# [UNK][UNK][UNK][UNK] 조[UNK]우 선동[UNK] [UNK]독[UNK]과[UNK][UNK]께[UNK][UNK][UNK] [UNK]전[UNK]고[UNK]
# 조별 예선 탈락과 독일을 상대로 고전을 면치 못했습니다.
#
# ynat-v1_train_00124
# 발언하[UNK] 박광[UNK]
# 박지성 발언 논란
#
# ynat-v1_train_00125
# [UNK]자배구[UNK]대[UNK]팀[UNK]코[UNK]진 구성 완료[UNK]트[UNK][UNK]너에 정기혁
#
# ynat-v1_train_00138
# 삼성 빅스[UNK] 개발자데[UNK][UNK][UNK][UNK]월 서울[UNK] 첫 [UNK]최
# 삼성이 빅스를 개발하는 데는 월 서울 첫 개발자가 필요했습니다.
#
# ynat-v1_train_00139
# 떼었[UNK] 붙였다 액세서리[UNK] 스마[UNK]폰 업[UNK]레이드
# 핸드폰 액세사리 떼고 붙였더니 스맛폰이 됐어요
#
# ynat-v1_train_00140
# 무등산에서 광주지역 올해 첫 얼음 관찰
# 광주에서 올해 처음으로 얼음이 관측되었습니다.
#
# ynat-v1_train_00141
# 알림톡 무단 [UNK]송[UNK][UNK][UNK][UNK][UNK][UNK]출 [UNK]카[UNK][UNK][UNK][UNK]징[UNK]
# 카카오톡 무단 전송 알람 발송 경고 메시지
#
# ynat-v1_train_00142
# [UNK]대통령 [UNK] [UNK][UNK] 국회의원과 [UNK][UNK][UNK]분 면담[UNK]사드 민심 청취
# 대통령 탄핵안 가결 후 대통령과 국회의원, 지역구 의원과의 면담이 이루어졌습니다.
#
# ynat-v1_train_00143
# 지소미아 종료까지 [UNK]일[UNK][UNK] 압박 속 고민 깊어지는 [UNK]대통령
# 한미일 군사동맹 강화 압박에 고심하는 대통령
#
# ynat-v1_train_00144
# 호텔서 스타 셰프 음식 만난다[UNK]더플라자 레스토랑 [UNK]곳 오픈
# 특1급 호텔인 더 플라자 호텔에서 유명 셰프가 만든 음식을 맛볼 수 있는 레스토랑이 문을 엽니다.
#
# ynat-v1_train_00145
# 우리은행 박혜진 연봉 [UNK]억원으로 [UNK]년 연속 연봉 퀸
# 하나원큐 박지수 연봉 1억 5천만원으로 [2021-2022]연속 연봉퀸 등극
#
# ynat-v1_train_00146
# [UNK] 친박 원내[UNK]표[UNK][UNK]보[UNK]유[UNK] [UNK]단[UNK]화[UNK]홍문[UNK][UNK][UNK][UNK][UNK]도[UNK]종합
# 친이계 탈당, 친박근혜계 화해, 홍준표 대표 선출
#
# ynat-v1_train_00147
# 도자기[UNK]작품[UNK][UNK]상[UNK][UNK][UNK][UNK]람객들
# 분청사기 상감모란문 정병
#
# ynat-v1_train_00148
# 시리보다 내가 낫다[UNK]빅스비의 세로드립 도발종합
# Siri is better than I am. 빅스비, 시리의 세로 드립에 대한 도발
#
# ynat-v1_train_00149
# 분당[UNK][UNK][UNK] [UNK][UNK][UNK][UNK][UNK][UNK][UNK][UNK][UNK][UNK] 야[UNK][UNK][UNK]대[UNK][UNK][UNK]대립
# 분당과 대구의 야당 대 여당 대립
#
# ynat-v1_train_00150
# [UNK][UNK]월 소비자 지갑을 열어라[UNK]유통업계 할인 경쟁 격화
# 유통업계, 소비자를 유혹하기 위한 할인 경쟁이 격화되고 있습니다.
#
# ynat-v1_train_00151
# 한국형 발사체 [UNK][UNK][UNK] 엔진 첫 연소시험 성공
# 누리호 엔진 1차 발사에 성공
#
# ynat-v1_train_00152
# 김정은 [UNK]향[UNK][UNK][UNK] [UNK]산시 [UNK][UNK]
# 홍콩 시위 참여 여성 경찰서에서 알몸 수색 강요당해
# 경찰, 여성 시위대 체포 후 수갑 채운 채로 경찰서로 연행, 수배자 검거에 협조하지 않을 경우 신원 확인을 위해 알코올 소독 후 옷을 모두 벗기고 수색을 진행하겠다고 협박
#
# ynat-v1_train_00166
# 삼성 세계 최초 후면 쿼드카메라 탑재 갤럭시[UNK][UNK] 공개
# 삼성이 세계 최초로 후면에 4개의 카메라를 탑재한 갤럭시를 공개했습니다.
#
# ynat-v1_train_00167
# 손흥민 [UNK][UNK]대표팀 합류 시점은[UNK][UNK][UNK]일 소집 참가 어려워
# 한국 축구 대표팀에 합류할 수 있을지는 불투명합니다.
#
# ynat-v1_train_00168
# [UNK]말[UNK][UNK] 여행 [UNK][UNK][UNK] [UNK][UNK]의 [UNK][UNK][UNK]을 반[UNK]는 [UNK]딧[UNK][UNK][UNK][UNK]짝
# "말" 여행은 "반대"하는 "짝"을 찾지 못했습니다.
#
# ynat-v1_train_00169
# [UNK][UNK] [UNK]사채 [UNK]행[UNK][UNK][UNK][UNK]조원[UNK][UNK][UNK]대비[UNK][UNK][UNK][UNK][UNK]
# 사채 규모 100조 원 돌파 대비
#
# ynat-v1_train_00170
# [UNK]이트삭[UNK][UNK][UNK]수 그[UNK]달 영입[UNK][UNK]년[UNK] [UNK]천[UNK][UNK][UNK][UNK] 달러
# 이트삭 영입에 1,000만 달러 이상 지출한 것으로 알려져 있습니다.
#
# ynat-v1_train_00171
# [UNK]이란 상대 국적자 체포 갈등[UNK]구금 중 학대 서로 비방
# 이란과 상대 국가 국적을 가진 남성이 체포되어 구금 중에 학대를 받았다는 주장이 제기되었습니다. 양측은 서로 상대방을 비난하며 갈등을 빚고 있습니다.
#
# ynat-v1_train_00172
# [UNK] 미네소타[UNK][UNK][UNK]람[UNK]장 입구[UNK] [UNK]격[UNK] 명 부상
# 미니애폴리스 세이프코 필드 입구에 차량 돌진, 선수 3명 부상
#
# ynat-v1_train_00173
# 홍남기 미래부 [UNK]차관 서울혁신센터 등 방문
# 미래창조과학부 미래전략정책관 홍 남기 차관이 서울 혁신센터를 방문하여 직원들을 격려했습니다.
#
# ynat-v1_train_00174
# [UNK]페이오[UNK]중동서[UNK][UNK][UNK][UNK][UNK]국[UNK][UNK]동[UNK][UNK][UNK]구[UNK]이란[UNK]고[UNK] 강[UNK]종[UNK]
# 페이오니아스 중동에서 국적을 가리지 않고 활동하는 그리스의 축구 선수로 알려져 있습니다.
#
# ynat-v1_train_00175
# 북한 사이버 공격 집단 세계 은행들 상대 [UNK]천억 탈취종합
# 북한이 세계은행들을 상대로 사이버 공격을 가해 천억 달러 이상의 탈취를 시도한 것으로 알려져 충격을 주고 있습니다.
#
# ynat-v1_train_00176
# [UNK]발사체에 미일 당국자 통화[UNK]한미일 협력 확인
# 한미일 3국 간 협력 관계를 확인하는 전화 통화였습니다.
#
# ynat-v1_train_00177
# 명[UNK] 옮[UNK] 는 즐[UNK]움[UNK]필사 [UNK]문[UNK]지 문[UNK][UNK][UNK]간
# 등[UNK] 수[UNK][UNK]확[UNK][UNK]앞[UNK] [UNK][UNK][UNK][UNK]경
# 올림픽 축구 예선 경기 앞당겨져
#
# ynat-v1_train_00191
# [UNK][UNK][UNK][UNK][UNK][UNK][UNK] 다저스 [UNK]년 연속 [UNK][UNK] 유력하지만 우승은 글쎄[UNK]
# LA다저스는 연속 우승 가능성이 높지만 우승을 장담할 수는 없습니다.
#
# ynat-v1_train_00192
# [UNK][UNK][UNK]뚝 떨어[UNK][UNK][UNK][UNK][UNK][UNK]출[UNK][UNK][UNK][UNK]에[UNK] [UNK][UNK]도 [UNK][UNK]으로 [UNK]라
# 뚝 떨어지다, 출렁거리다, 흔들리다, 불안정하다, 위태위태하다 등 다양한 표현이 사용될 수 있습니다.
#
# ynat-v1_train_00193
# 구글 [UNK]세대 크롬캐스트 출시[UNK]신세계아이앤씨 단독 판매종합
# 구글이 주도하는 차세대 미디어 스트리밍 디바이스 '크롬 캐스트'가 출시됐다. 신세계I&C가 단독으로 판매한다.
#
# ynat-v1_train_00194
# 서울자유시민대학 초대 학장에 정재권 전 한겨레신문 논설위원
# 서울시민대학 초대회장, 서울대학교 언론인 양성과정 수료, 전 서울신문 편집부국장, 현 자유언론실천재단 이사, 한국신문방송편집인협회 이사.
#
# ynat-v1_train_00195
# 웨이포트 [UNK]월 [UNK][UNK]일 상장폐지 신청 예정
# 위완화(위안화) 평가절하로 중국 기업 줄도산 우려로 월요일 상장 폐지 신청할 것으로 예상됩니다.
#
# ynat-v1_train_00196
# [UNK][UNK][UNK] [UNK]강[UNK]대[UNK] 발[UNK][UNK][UNK]알[UNK][UNK][UNK]리[UNK]뮌헨 맞[UNK][UNK]
# 강팀 대항전 발렌시아 대 마인츠 리버플 맞대결
#
# ynat-v1_train_00197
# 남[UNK]정[UNK]회[UNK] [UNK][UNK] 준비가 생명[UNK]남북[UNK]리허설 또 리허설
# 남북관계 준비는 생명과도 같다. 남북 관계 개선을 위한 남북 당국 간 대화 재개를 촉구한다.
#
# ynat-v1_train_00198
# 버닝썬 게이트 다룬 [UNK][UNK][UNK] 그것이 알고 싶다 [UNK][UNK][UNK][UNK][UNK]
# '그것이 알고싶다'에서 다뤘지만, 아직 밝혀지지 않은 사건 '버닝 썬'에 대해 다루는 프로그램 '알고 싶다'를 말합니다.
#
# ynat-v1_train_00199
# 현대차 현대차증권 [UNK][UNK][UNK] [UNK][UNK][UNK]억원 매수
# 현대차가 현대차증권을 1,000억 원어치 매수했습니다.
#
# ynat-v1_train_00200
# 갤[UNK][UNK][UNK] [UNK][UNK][UNK]부터 [UNK][UNK]까[UNK] 환불[UNK][UNK][UNK][UNK][UNK]만원 [UNK][UNK]도
# 갤럭시부터 GALAXY까지, 환불 금액 만원도 안 돼
#
# ynat-v1_train_00201
# 빛으로 작동하는 나노선 트랜지스터 개발 성공
# 광전자 소자 개발로 빛을 전기 신호로 변환하는 기술의 발전이 예상되며, 이는 광통신, 광센서 등 다양한 분야에 응용될 수 있습니다.
#
# ynat-v1_train_00202
# 이청용이 러시아 프리미어리그 이적에 청신호를 켰습니다.
#
# ynat-v1_train_00241
# [UNK][UNK] [UNK][UNK] 모바일 시큐리티 [UNK][UNK][UNK][UNK] [UNK][UNK]로드 돌파
# 모바일 보안 취약점 돌파
#
# ynat-v1_train_00242
# 배구 남녀 대표팀 임도헌라바리니 감독 보령서 짧은 상견례
# 한국 배드민턴 남녀 국가대표팀 감독과 코치진이 보람여고 체육관에서 첫 공식 미팅을 가졌습니다.
#
# ynat-v1_train_00243
# [UNK][UNK]자베스 여[UNK][UNK]정치권에[UNK][UNK][UNK][UNK]트 타협 촉구
# 제임스 자비스 전 메사추세츠 주지사, 정치권에 '타협' 촉구
#
# ynat-v1_train_00244
# [UNK][UNK][UNK][UNK][UNK]전 [UNK]기[UNK]맞먹[UNK] 사[UNK] [UNK]양[UNK][UNK][UNK]전소 [UNK][UNK][UNK][UNK]
# 전성기 맞먹는다 사나이들 전소
#
# ynat-v1_train_00245
# [UNK][UNK][UNK][UNK]명장 바비 콕스 [UNK][UNK][UNK][UNK]로[UNK][UNK][UNK]
# 명장 '바비' 코크 감독으로 별세...영국 축구계 애도 물결(종합)
#
# ynat-v1_train_00246
# [UNK]공[UNK] 파키스탄 내 [UNK][UNK] [UNK][UNK] [UNK][UNK][UNK][UNK]등 [UNK]고조종합
# 파키스탄에서는  지진, 홍수, 가뭄 등 자연재해가 빈번하게 발생하고 있습니다. 이러한 자연재해로 인해 많은 인명피해와 재산피해가 발생합니다.
#
# ynat-v1_train_00247
# [UNK]시판 코[UNK]아 [UNK][UNK][UNK]페[UNK][UNK][UNK]
# 코카-콜라 코-아 음료수
#
# ynat-v1_train_00248
# 바르샤 이승우[UNK][UNK][UNK][UNK]네[UNK]란드 팀으로[UNK]임대 가[UNK][UNK]
# 이청용과 이승우가 스페인 프리메라리가 팀에서 임대 생활을 시작합니다.
#
# ynat-v1_train_00249
# [UNK]대통령[UNK][UNK]후방테러[UNK]대비위해 [UNK]러방지법 [UNK][UNK][UNK][UNK]
# 대통령 후방지 테러 대비 위해 러시아 방지법 제정
#
# ynat-v1_train_00250
# 민주[UNK]성사 앞[UNK][UNK]북미정[UNK]회담에 [UNK]색[UNK]야당[UNK] 힘 [UNK][UNK]야
# 민주당 성사 앞에 북·미 정상회담에 색깔론 야당의 힘 약해져
#
# ynat-v1_train_00251
# 삼성[UNK]애플[UNK][UNK][UNK][UNK]구글 스마트폰 가을대전 임박
# 삼성전자와 애플, 구글의 스마트폰 대전이 가을 대전을 예고하고 있습니다.
#
# ynat-v1_train_00252
# 트럼프 드론 격추에 [UNK]이란 보복공격 승인했다 돌연 철회종합[UNK]보
# 도널드 트럼프 미국 대통령이 이란 군부 실세인 가셈 솔레이마니 사령관을 드론 공격으로 살해한 것에 대한 보복으로 이란에 대한 군사 보복을 승인했지만, 이란의 보복 공격이 임박했다는 정보가 입수되자
#
# ynat-v1_train_00253
# 폴란드서 이란 겨냥 [UNK]주도 [UNK][UNK]여개국 중동문제회의 시작
# 이란을 겨냥한 중동 문제 회의가 이란에서 시작되었습니다.
#
# ynat-v1_train_00254
# 네이버 인공지능으로 식당 예약 전화 받는 [UNK][UNK] 콜 공개
# 인공지능이 전화로 식당을 예약하는 콜이 공개됐다. 네이버가 개발한 인공지능(AI) 콜센터 '클로바 케어콜'이 그 주인공이다. 이 콜센터는 전화가 걸려오면 문맥을 이해하고 응대
#
# ynat-v1_train_00255
# 봄비 머금은 꽃망울
# 꽃이 봄비를 머금고 있다.
#
# ynat-v1_train_00256
# 게[UNK]판 [UNK][UNK][UNK] [UNK][UNK][UNK][UNK][UNK] 앱[UNK]핑크퐁 튜[UNK] 출시
# 앱핑고 출시, 핑크팬더 캐릭터로 제작된 어린이 교육용 앱
#
# ynat-v1_train_00257
# [UNK]직언론인[UNK]조[UNK]족[UNK]장애인[UNK]시[UNK] 폭 [UNK]히는 시인[UNK]
# 언론직종에 종사하는 장애인, 폭력을 휘두르는 시인
#
# ynat-v1_train_00258
# 초등학생들 경북도청 [UNK]들[UNK]
# 경상북도청 초등돌봄전담사들
#
# ynat-v1_train_00259
# [UNK][UNK] 인공지능 기술로 목소리 찾아드려요[UNK]목소리 찾기 프로젝트
# 인공지능 기술을 활용한 음성 찾기 서비스 제공
#
# ynat-v1_train_00260
# 아이폰[UNK][UNK] 프로 써보니[UNK]프로다운 카메라 성능 기대 이상
# 애플 아이폰 프로 카메라, 프로다운 성능 보여줘
#
# ynat-v1_train_00261
# [UNK][UNK][UNK][UNK]위[UNK]혁신[UNK] 출[UNK][UNK][UNK][UNK][UNK][UNK]박 [UNK]발 작용한[UNK][UNK]
# 혁신이 출현한 후 박탈 작용을 일으킨다.
#
# ynat-v1_train_00262
# 국립민속박물관 아카이브 만들기 특별전 개최
# 민속 박물관 아카이빙 특별 전시회 개최
#
# ynat-v1_train_00263
# 임도헌 감독 젊은 선수들 자신감 얻었다[UNK]내년 [UNK]월 진짜 승부
# 한국 남자 배구 대표팀 감독이 말한 내년 월 진짜 경기에서 승리할 수 있는 자신감을 얻었다고 합니다.
#
# ynat-v1_train_00264
# 대우[UNK]선해양 [UNK]천[UNK][UNK][UNK]억원[UNK][UNK][UNK] [UNK][UNK][UNK] 운[UNK]선 [UNK]척[UNK]수주
# 대한해운선 해양공사 천억원대 선박 수주에 척척
#
# ynat-v1_train_00265
# [UNK][UNK]광년 떨어진 곳에서 지구 크기 삼형제 발견
# 광년은 빛이 1년 동안 가는 거리를 말하며, 지구 크기는 태양과 지구 사이의 거리를 기준으로 합니다.
#
# ynat-v1_train_00266
# [UNK]말 [UNK] 여[UNK] [UNK]주권 인류무형문화유산 해[UNK][UNK]화를 [UNK]나다[UNK][UNK][UNK][UNK][UNK] [UNK]비[UNK][UNK][UNK]
# 말(馬) 기(技) 여(女) 주(州)권(主權) 인(人類) 무(武)형(形) 문화유산(文化遺産
#
# ynat-v1_train_00267
# [UNK][UNK]출신 왕웨이중 [UNK][UNK]복귀[UNK]에인절스전 [UNK]이닝 무실점
# 대만 출신 왼손 투수 웨이쥔펑이 복귀전을 치렀고, 에인젤스전에서 이닝을 무안타로 막았습니다.
#
# ynat-v1_train_00268
# 그[UNK]픽 [UNK][UNK][UNK][UNK][UNK][UNK][UNK]리 결함
# 골든 글러브 수상자 선정에 결함이 있습니다.
#
# ynat-v1_train_00269
# 차범근과 손흥민을 관통하는 공통점[UNK][UNK][UNK]와 [UNK] 그리고 아홉수
# 한국 축구 대표팀의 차붐과 토트넘의 손케인, 그리고 9월 A매치 2연전을 앞두고 있는 두 선수의 공통점은 무엇일까요?
#
# ynat-v1_train_00270
# 신년사 손학규 다당제[UNK]합의제로 희망 드리는 정치 실천
# 새해 인사 손석희 다자구도 합의제 도입 희망하는 정치실천
#
# ynat-v1_train_00271
# 노벨평화상 소식에 아프리카 환호[UNK]각국 정상 환영 잇따라
# 유엔 평화상 수상에 아프리카 각국 환영
#
# ynat-v1_train_00272
# [UNK]가 전한 설 민심[UNK]정권교체 해달라 자만말라 쓴소리도
# 민심은 정권교체를 원한다. 자만을 경계하고 쓴소리를 귀담아들어야 한다.
#
# ynat-v1_train_00273
# 위안부 피해자 그림 선생님이 전하는 이야기
# 일본군 '위안부' 피해자 할머니들의 이야기
#
# ynat-v1_train_00274
# [UNK] 물가 [UNK][UNK] 초미세먼지[UNK]세계 최[UNK][UNK]관[UNK][UNK][UNK][UNK] 걸림돌
# 물가는 세계 최하위권, 미세먼지는 세계 최고 수준
#
# ynat-v1_train_00275
# 그래픽 내년 코스피 전망치
# 2021년 코스피 지수 전망: 3000P~3200P 예상
#
# ynat-v1_train_00276
# [UNK][UNK] 황[UNK]연휴[UNK]해[UNK] [UNK][UNK][UNK]박 이용권[UNK]드려[UNK]
# 황제휴가, 황제의 박탈권, 휴가를 이용하세요.
#
# ynat-v1_train_00277
# [UNK][UNK][UNK]엔터테인먼트 [UNK]분기 영업익 [UNK][UNK][UNK]억원[UNK][UNK][UNK][UNK] 증가
# 엔터주 3분기 실적 발표, 영업이익·순이익 모두 증가
#
# ynat-v1_train_00278
# [UNK][UNK] [UNK][UNK] [UNK][UNK][UNK][UNK] 선[UNK][UNK]인[UNK][UNK]능 분[UNK][UNK][UNK][UNK]천[UNK]원 투[UNK]종합
# 선수는 능력은 뛰어나지만 돈은 천 원밖에 없습니다. 투자는 종합적인 분석을 통해 이루어져야 합니다.
#
# ynat-v1_train_00279
# 최지만 시즌 첫 [UNK]루타[UNK]종아리 통증으로 교체
# 추신수, 시즌 10호 홈런 포함 3안타 맹타...텍사스 4연패 탈출
#
# ynat-v1_train_00280
# [UNK]대통령 호[UNK][UNK][UNK]거소[UNK]방문[UNK]호 주석 본[UNK]으[UNK] 부패 없어[UNK][UNK]것
# 대통령 거소 방문 시 호주는 부패가 없는 것으로 알려져 있습니다.
#
# ynat-v1_train_00281
# 춘천 [UNK][UNK][UNK] 나이야가라 한국방송대상 작품상 수상
# 춘천시 대상 수상작 '나이야 가라' 작품으로 방송대상에 선정
#
# ynat-v1_train_00282
# 콘테 첼시 감독 캉테 [UNK][UNK]로마전 출전여부 본인이 결정할 것
# 토트넘 감독, 케인 결장 시 캥테 선발 출전 여부 본인이 결정한다.
#
# ynat-v1_train_00283
# 부산국제코미디페스티벌에 참여합니다
# 코미디언들이 부산에서 축제를 연다.
#
# ynat-v1_train_00284
# 연천 영하 [UNK][UNK][UNK][UNK]도[UNK]경[UNK]북[UNK][UNK]오후부[UNK][UNK]강[UNK]위 풀려
# 강원도 연일 영하권 추위...오후부터 풀릴 듯
#
# ynat-v1_train_00285
# 드랙퀸 연극 조지 맥브라이드의 전설 내달 초연
# 트랜스젠더 배우가 주연으로 출연하는 연극 '조지 M. 브라이드'의 다음 달 초연이 예정되어 있습니다.
#
# ynat-v1_train_00286
# 이스라엘 역사 녹은 희비극 말 한 마리[UNK]
# 희극과 비극이 뒤섞인 말의 한 마리가 전하는 메시지
#
# ynat-v1_train_00287
# [UNK]기소식[UNK]부[UNK][UNK] 내[UNK] [UNK][UNK][UNK]일 [UNK][UNK]도 [UNK][UNK][UNK]화재 대[UNK]제
# 소식에 따르면 내일부터도 화재 대참사가 계속될 것으로 예상됩니다.
#
# ynat-v1_train_00288
# 게시판 제[UNK][UNK]회 한국출판학회상에 천재교육 등 선정
# 한국 출판학회상 수상자 선정
#
# ynat-v1_train_00289
# 이인제 충청을 젊은 희망의 땅으로 만들것 충남지사 출마 선언
# 이해찬 세종시 원안 추진과 행정중심복합도시 건설을 위해 노력할 것입니다.
#
# ynat-v1_train_00290
# [UNK]말 [UNK][UNK]여행 제주[UNK][UNK]취향[UNK][UNK][UNK][UNK]나자[UNK][UNK]대야 날릴[UNK][UNK]색 계곡[UNK][UNK]다 축제
# 말 여행 제주 취향이나자 대야를 날려야 할 색계곡 축제
#
# ynat-v1_train_00291
# [UNK]징[UNK][UNK]코데[UNK]컴바[UNK][UNK]다[UNK] [UNK]스닥[UNK][UNK]총[UNK][UNK][UNK][UNK]종[UNK]
# 코스닥 종가 기준 사상 최고치 경신
#
# ynat-v1_train_00292
# 네이버뮤직 바이브로 통합[UNK]기존 서비스 내년 종료
# 멜론, 지니, 벅스, 소리바다 등 기존 서비스 종료 및 네이버 뮤직바이브 서비스 통합 예정
#
# ynat-v1_train_00293
# 문 대통령 안타까움 금할 수 없어[UNK]사망자 최소화 만전 기하라
# 문재인 대통령 애도 성명 발표, 사망자 최소화를 위한 만전을 기할 것을 지시
#
# ynat-v1_train_00294
# 스페인 [UNK][UNK]회 연속 월드컵 본선 진출[UNK]이탈리아 [UNK][UNK]행종합
# 스페인은 월드컵 연속 진출에 실패하고 이탈리아로 향합니다.
#
# ynat-v1_train_00295
# 유럽 최악 한파에 난민들 피해속출[UNK]폐렴[UNK]저체온증 극심
# 난방비 폭탄에 노숙자·난민 피해 속출
#
# ynat-v1_train_00296
# 송[UNK]섭 [UNK] [UNK]회[UNK][UNK] [UNK][UNK][UNK]전국구 [UNK]원만[UNK][UNK]선
# 전국구 원맨쇼 송중기 전국구로 뜬다
#
# ynat-v1_train_00297
# [UNK] [UNK] [UNK]동당대회 [UNK]시하면서 만약의[UNK]상황 대[UNK]
# 동지대회에서 시한을 정해놓고 만약에 대비하는 것이 아니라, 시기를 정해 놓는 것입니다. 만약이라는 것은 상황에 따라 달라질 수 있기 때문입니다. 따라서 "만약의 상황"이라는 표현은 적절하지 않습니다.
#
# ynat-v1_train_00298
# 리[UNK]에겐 인격적 소[UNK][UNK]력 중요[UNK][UNK]과만중[UNK][UNK]독불[UNK]군형은 [UNK][UNK]
# 레오나르도 디카프리오에게는 인간적인 소질과 인품만 중요하며, 독불장군형 인간형은 아닙니다.
#
# ynat-v1_train_00299
# 푸[UNK] 살만[UNK]사우디[UNK][UNK]왕과[UNK][UNK][UNK][UNK][UNK]유시[UNK] [UNK]조 지속 합의종합
# 사우디아라비아 왕실과 시아파 후티 반군 간 휴전 합의
#
# ynat-v1_train_00300
# 김정은 탑승 추정 [UNK] 열차 단둥 통과[UNK][UNK][UNK]여시간 여정 개시
# 김여정 추정 인물로 추정되는 북한 열차가 압록강 철교를 통과한 것으로 알려졌습니다. 북한 김일성 주석의 생가인 만경대 방문 등 여정을 시작한 것으로 보입니다.
#
# ynat-v1_train_00301
# 아시안게임 응원석엔 하나된 함성 벤치엔 우정의 미소[UNK][UNK][UNK][UNK]
# 제17회 자카르타-팔렘방 아시아경기대회에서는 하나 된 함성과 함께 선수들을 응원하는 모습과 함께, 경기장에서는 우정을 나누는 모습도 볼 수 있었습니다.
#
# ynat-v1_train_00302
# 문대통령 미중러 협력[UNK]아세안 동행[UNK]비핵화 동력 보전했다
# 文대통령, 미·중·러와 협력하며 아세안에 '동행'했지만, 비핵화의 동력은 잃었다
#
# ynat-v1_train_00303
# 아랍권 반[UNK]란[UNK]정상회의 [UNK]춰 [UNK][UNK][UNK][UNK] 이란 맹[UNK]종합
# 중동 반이란 정상회의 개최...이란 맹비난
#
# ynat-v1_train_00304
# 평양정상회담 남북 정상 오찬장도 함께
# 평양을 방문 중인 문재인 대통령과 부인 김정숙 여사는 9월 18일 평양 옥류관에서 김정은 국무위원장과 부인 리설주 여사와 함께 만찬을 가졌습니다. 이 자리에는 김영남 최고인민회의 상임위원장, 김여정
#
# ynat-v1_train_00305
# 답[UNK]한[UNK][UNK]빛 하[UNK][UNK]경기[UNK] 초미세[UNK]지 주[UNK][UNK] [UNK][UNK][UNK]으[UNK][UNK][UNK]대
# 빛나는 별 하이라이트 경기 초미세한 지구의 대기권
#
# ynat-v1_train_00306
# [UNK][UNK] 연말연시 맞아 네트워크 특별대책 마련
# 네트워크 장애 예방을 위한 특별 대책 마련
#
# ynat-v1_train_00307
# 광[UNK][UNK]북구[UNK]취[UNK]계[UNK] [UNK][UNK]나[UNK]
# 광주 북구 취생몽사(金生夢死)
#
# ynat-v1_train_00308
# 네이버 전문자료 검색 내년 안에 구글 따라잡을 것
# 구글이 네이버를 추월하는 것은 시간 문제
#
# ynat-v1_train_00309
# 민주 광역단체장 후보 면접[UNK]지방선거 당내 경쟁 개막
# 6·1 지방선거 더불어민주당 후보 경선 개막
#
# ynat-v1_train_00310
# [UNK][UNK]텔레콤 충청 지역 폭우피해 통신망 복구
# 충청 지역에 폭우가 내리면서 SK텔레콤의 통신망이 일부 복구됐습니다.
#
# ynat-v1_train_00311
# 경제 윤종원 일자리 정태호 [UNK]수석 교체[UNK]민생[UNK]고용 드라이브종합[UNK]보
# 청와대 경제 수석 교체, 일자리 수석 정무·정책·사회혁신, 민생경제·고용노동, 경제정책 총괄·조정, 종합적인 경제 정책 추진
#
# ynat-v1_train_00312
# [UNK]대통령 한불 비즈니스포럼[UNK][UNK]콘 참석[UNK]파리서 경제[UNK]문화외교
# 노무현 대통령 한-불 경제인 포럼 참석, 파리에서 경제·문화 외교 펼쳐
#
# ynat-v1_train_00313
# 공사기간[UNK]비용[UNK][UNK][UNK][UNK][UNK] [UNK][UNK][UNK][UNK][UNK][UNK][UNK]크[UNK] [UNK][UNK]사업[UNK]주[UNK]
# 공사지연 비용[비용]공사 기간[기간][기간] 크[크] 사업[사업][사업] 주[주]
#
# ynat-v1_train_00314
# 외국인에게 말만 하세요 한컴 이어폰형 통역기 [UNK][UNK][UNK]서 첫선
# 한글과컴퓨터가 개발한 통번역기가 첫선을 보였습니다. 이 제품은 스마트폰과 연동해 사용할 수 있으며, 한국어와 영어, 중국어, 일본어 등 4개 언어를 지원합니다.
#
# ynat-v1_train_00315
# 이라크 프랑스인 [UNK][UNK] 조직원 가차없이 사형선고
# 프랑스, 이라크에서 테러 용의자에 대해 가혹한 형벌 시행
#
# ynat-v1_train_00316
# 아힘 프라이어가 소개하는 반지 [UNK]부작
# 하이메 아욘이 디자인한 '반지 부작'
#
# ynat-v1_train_00317
# 탈북 도와[UNK][UNK]한국계[UNK]영[UNK][UNK][UNK][UNK]왕[UNK] 국가공[UNK]훈장 [UNK]아
# 북한을 탈출해 한국에 정착한 한국계 영주권자 국가 공로 훈장 수훈
#
# ynat-v1_train_00318
# 프로농구 인삼공사 컬페퍼 햄스트링 부상[UNK]교체할 듯
# KBL 프로 농구 안양 KGC인삼공사의 외국인 선수 오세근이 왼쪽 종아리 근육 부상으로 교체될 것으로 보입니다.
#
# ynat-v1_train_00319
# 김현미 전월세상한제 신규 계약 적용 고려할 점 많아 신중론
# 전월세 상한제 적용 시 고려해야 할 사항이 많아 신중한 접근이 필요합니다.
#
# ynat-v1_train_00320
# 등단 [UNK][UNK]년 장[UNK]남[UNK][UNK]인 [UNK]가[UNK]나[UNK] 지[UNK]줬죠
# 데뷔한 지 20년이 넘은 가수가 있습니다.
#
# ynat-v1_train_00321
# [UNK] 추미애 긴급회동 제안에 정해진 바 없다
# 법무부 장관과 검찰총장이 긴급 회동을 제안한 것으로 알려졌지만, 법무부와 검찰 모두 이에 대해 확인해 줄 수 없다는 입장을 밝혔습니다.
#
# ynat-v1_train_00322
# 필리핀 국방장관 몰래 군부대에 [UNK] 통신 시설 설치 허용[UNK]재검토
# 필 국방부, 군부대 내 통신시설 설치 재검토
#
# ynat-v1_train_00323
# 청[UNK]율[UNK][UNK][UNK][UNK]김어준[UNK]뉴[UNK]공장 청취[UNK][UNK][UNK][UNK]는[UNK][UNK]찌
# 최순실 국정농단 청문회 녹취록 공개는 찌라시 언론의 찌질한 짓이다.
#
# ynat-v1_train_00324
# 프[UNK][UNK]구[UNK][UNK] 해체 위[UNK] [UNK]산 어[UNK]선한[UNK][UNK]위[UNK][UNK][UNK]승[UNK]로 [UNK][UNK]
# 프로야구 해태 타이거즈 팀 창단 이후 첫 우승
#
# ynat-v1_train_00325
# 그[UNK]픽 [UNK]택[UNK][UNK][UNK]가[UNK][UNK]현실화율[UNK]세[UNK] 산[UNK]식
# G리그 픽 택하면 현실화율이 어떻게 되나요? 세 가지 방법으로 계산해 봅시다.
#
# ynat-v1_train_00326
# 지구 임계온도 [UNK][UNK][UNK]도 목표 촉구 [UNK]인 시위
# 태양계 경계 온도 도달 촉구 시위
#
# ynat-v1_train_00327
# [UNK]일[UNK][UNK]연[UNK] 의원들과[UNK][UNK][UNK][UNK]는 [UNK][UNK]연 [UNK][UNK]
# 연이은 의원들의 불출마 선언과 탈당 선언
#
# ynat-v1_train_00328
# 버려진 튜브로 만든 설치미술
# 환경 보호를 위한 설치 미술 작품으로 재활용이 가능한 소재를 사용하여 환경 오염을 줄이기 위한 노력의 일환으로 제작되었습니다.
#
# ynat-v1_train_00329
# [UNK]김정[UNK][UNK]평양[UNK] 제[UNK][UNK] [UNK]래과학자거리 [UNK]설 지시
# 김정은, 평양 과학자 거리 건설 현장 시찰 지시
#
# ynat-v1_train_00330
# [UNK][UNK] [UNK][UNK] [UNK] 폰 [UNK] 단독 출시
# 삼성 갤럭시 S4 LTE-A 출시
#
# ynat-v1_train_00331
# 섬들의 근대화는 달랐다[UNK]일제가 쓰고 버린 태평양 섬 이야기
# 일제 강점기 태생 섬의 근대화는 달랐습니다. 일제 때 쓰이고 버려진 섬 이야기는 어떤 내용이었을까요?
#
# ynat-v1_train_00332
# 과학전람회 대통령상에 충북과학고생 최경준[UNK]손승연
# 대통령과학장려상 수상자 명단 발표
#
# ynat-v1_train_00333
# 무선 장비로 침입자 막는다[UNK] [UNK][UNK]텔레캅 새 보안 서비스종합
# 무전기나 무선 통신 장비를 이용해 출입자를 감지하고 차단하는 보안 서비스가 등장했다. 서울 구로구에 본사를 둔 에스원(012750)은 출입통제시스템에 무선통신 기술을 접목한 '무선 출입관리 시스템'
#
# ynat-v1_train_00334
# 중소기업 [UNK][UNK] 경기[UNK]망 부정적[UNK]인건비 올라[UNK]최대 애로
# 경기침체로 중소기업의 인력난과 인건비 상승이 최대 애로로 작용하고 있습니다.
#
# ynat-v1_train_00335
# [UNK]승하러 왔죠[UNK]전광인[UNK]우승 한 풀[UNK] [UNK][UNK][UNK][UNK]지
# 전광인은 우승을 위해 왔고, 한풀이 끝났습니다. 한국전력은 풀세트 접전 끝에 현대캐피탈을 3-2(25-22, 25-23, 19-25, 15-10, 8-6)
#
# ynat-v1_train_00336
# 닷새째 경찰에 포위된 홍콩 이공대
# 5일째 경찰과 시위대 대치 중
#
# ynat-v1_train_00337
# [UNK] 대구[UNK]경북 공천면접심사[UNK]현역 [UNK][UNK] 진박 격돌
# 프로농구 [UNK][UNK][UNK] 후보 두경민 많은 것을 배운 시즌
# 농구 프로 2년차, 많은 걸 배우고 성장한 시즌
#
# ynat-v1_train_00353
# 베스트셀러 가벼운 에세이류 강세 계속
# 올해도 에세이의 강세가 계속될 것으로 예상됩니다.
#
# ynat-v1_train_00354
# [UNK]움[UNK]권[UNK]올[UNK] 면[UNK][UNK] 시[UNK] [UNK][UNK][UNK][UNK]이상 [UNK]장[UNK]가[UNK][UNK]
# 움베르투 코엘류 감독 경질 이후 포르투갈 축구 국가대표팀 성적 부진으로 인해 이상 징후가 나타나기 시작했습니다.
#
# ynat-v1_train_00355
# 이달의 편집상에 매일신문 공부까지 거리두면[UNK] 등 [UNK]편
# 이달의 기자상 수상작에 '매일신문'의 '공부까지' 등 '거리두면', '등' 등의 문장이 포함된 기사가 포함되어 있습니다.
#
# ynat-v1_train_00356
# 조코위[UNK]김정[UNK] [UNK][UNK][UNK]여[UNK][UNK]석[UNK][UNK][UNK][UNK]민[UNK]보[UNK] 사[UNK][UNK] 내[UNK][UNK]
# 자카르타-팔렘방 아시안게임 폐막식 참석
#
# ynat-v1_train_00357
# 주말 [UNK] 여행 강원권 남한강축제서 무더위 날리자[UNK]속초는 피서철 이벤트
# 여름휴가, 강원도로 떠나자! 속초로 떠나볼까?
#
# ynat-v1_train_00358
# [UNK]란[UNK][UNK]럽 [UNK][UNK][UNK] [UNK]돌리면[UNK][UNK]대[UNK][UNK]맞대응
# UNK란은 락(Rock)의 준말이며, 대(大)는 큰 것을 의미합니다. 따라서, UNLOCK하면 록을 뜻하게 됩니다.
#
# ynat-v1_train_00359
# 홍영표 홍문종[UNK]염동열 체포동의안 부결에 사과[UNK]책임통감
# 민주당 홍익표 수석대변인, 염태영 수원시장, 김동연 전 경제부총리 겸 기재부 장관, 박남춘 인천광역시장 등 민주당 소속 광역단체장 3명이 연루된 공직선거법 위반 사건에 대한
#
# ynat-v1_train_00360
# 폭증한 신용대출도 가상화폐 시장으로 갔나
# 신용 대출이 가상 화폐로 이동하고 있습니다.
#
# ynat-v1_train_00361
# 삼성전자 주총[UNK]퍼스트무버로 거듭나겠다종합
# 삼성전자가 퍼스트 무버(First Mover·시장 선점자)로 자리매김하기 위해 주주총회에서 주주친화 정책을 강화하겠다고 밝혔다.
#
# ynat-v1_train_00362
# 프[UNK][UNK]구 롯데 [UNK]상문[UNK][UNK]독 [UNK][UNK][UNK] 사직구장[UNK] [UNK][UNK][UNK]
# 프로야구 롯데 자이언츠 구단주 사임, 구장 이름 변경 예정
#
# ynat-v1_train_00363
# [UNK][UNK][UNK][UNK][UNK] 온도따라 변하는 스마트 입자 개발
# 온도 변화에 따라 입자의 성질이 바뀌는 스마트입자를 개발하는 연구가 진행되고 있습니다.
#
# ynat-v1_train_00364
# [UNK]시[UNK]게[UNK] 김[UNK]범호 [UNK][UNK]상대[UNK][UNK][UNK]기[UNK][UNK]탄[UNK]바[UNK]인[UNK][UNK][UNK][UNK][UNK][UNK]
# 김범수, 상대 투수 기용 탄탄한 바인스인 활용
#
# ynat-v1_train_00365
# 지각 입장한 남북 선수단 그 사연은
# 남북 단일팀으로 출전한 여자 아이스하키 선수들이 경기장에 늦게 도착한 사연이 있습니다.
#
# ynat-v1_train_00366
# 스마트폰에 신용카드 대면 삑 새 본인 인증 나온다
# 지문 인식, 홍채 인식 등 다양한 생체인식 기술이 스마트폰에서 사용되고 있습니다.
#
# ynat-v1_train_00367
# 사람 닮아가는  [UNK][UNK]의[UNK]손[UNK][UNK][UNK]이[UNK]아 나무의[UNK] 조[UNK][UNK][UNK]공
# 사람의 손과 닮은 나무가 자라고 있습니다.
#
# ynat-v1_train_00368
# 삼성[UNK][UNK][UNK]하[UNK]닉[UNK][UNK][UNK]분기[UNK]도 반[UNK][UNK] [UNK][UNK][UNK]순항할[UNK][UNK]
# 삼성전자는 분기 실적도 호조세를 이어갈 것으로 예상됩니다.
#
# ynat-v1_train_00369
# [UNK][UNK][UNK]엔터[UNK][UNK]이코 가입[UNK] [UNK][UNK][UNK][UNK][UNK][UNK]제휴 [UNK]대할 [UNK]
# 엔터테이너스 코퍼레이션 가입, 이코 제휴
#
# ynat-v1_train_00370
# 한[UNK][UNK][UNK][UNK]주택브랜드 공작소 론칭
# 한국주택협회, 주택 브랜드 '공작(孔雀)' 론칭
#
# ynat-v1_train_00371
# 고침 체육신인 [UNK]순위 펄츠 복귀[UNK]필라델피아
# 농구 신인 드래프트에서 1라운드 1순위로 뽑힌 포틀랜드 트레일블레이저스의 포인트 가드 데이비드 로빈슨(21)이 복귀한 필라 델피아 세븐티식서스로 트레이드
#
# ynat-v1_train_00372
# 영상 최강 한파 패딩[UNK]목도리 중무장[UNK]전국 강추위에 꽁꽁
# 영하권 추위 전국 강타, 한랭질환자 속출...동파 신고도 급증 전국에 한파가 기승을 부리면서 영하 10도 안팎의 매서운 추위가 이어지고 있습니다. 기상청에 따르면 오늘 아침 최저기온은 서울
#
# ynat-v1_train_00373
# [UNK][UNK][UNK]개 언어 인도 힌디어 국어 지정 놓고 찬반 논란
# 인도에서 힌프디어를 공용어로 지정하는 것을 두고 찬성과 반대 의견이 대립하고 있습니다.
#
# ynat-v1_train_00374
# 터키군 시리아 진격[UNK]에르도안 평화의 샘 작전 개시 선언종합
# 터키는 시리아 북서부 이들리브주에서 시리아민주군(SDF)과 합동 군사작전을 개시한다고 공식 선언했습니다. 레제프 타이이프 에드로안 터키 대통령은 이날 TV로 생중계된 연설을 통해 "
#
# ynat-v1_train_00375
# 충북 한여름 무더위[UNK]날씨는 맑음
# 충청북도는 대체로 맑은 날씨를 보이고 있습니다.
#
# ynat-v1_train_00376
# 서[UNK][UNK][UNK][UNK]구팀[UNK][UNK][UNK]재 [UNK][UNK]핀 상용[UNK][UNK][UNK]술 세[UNK][UNK]최초 [UNK][UNK]
# 삼성 라이온즈 창단 첫 한국시리즈 우승
#
# ynat-v1_train_00377
# [UNK][UNK][UNK] 부산 엑스포서 해양안전 통신기술 시연
# 부산 세계 박람회에서 해양 안전 통신 기술 시연이 이루어졌습니다.
#
# ynat-v1_train_00378
# 중[UNK] [UNK][UNK][UNK][UNK]국회[UNK][UNK]들[UNK][UNK]핵 규탄 공[UNK][UNK]명서 채[UNK]
# 국회, 북한 핵규탄 결의안 채택하며 성명서 발표
#
# ynat-v1_train_00379
# 이[UNK]서 [UNK]국 강조[UNK][UNK]민[UNK][UNK] 캐[UNK]다서[UNK][UNK]정[UNK][UNK][UNK]의혹 [UNK][UNK] 비판
# 여기서 강조된 민감한 사안에 대한 의혹은 비판의 여지가 있습니다.
#
# ynat-v1_train_00380
# 러시아 시리아서 [UNK][UNK][UNK][UNK] 발사했나[UNK]러 국방부는 부인
# 시리아에서 러시아가 미사일을 발사했다는 보도는 사실이 아닙니다. 러시아 국방부 장관은 이를 부인했습니다.
#
# ynat-v1_train_00381
# [UNK] 어[UNK][UNK]결정하든 [UNK][UNK][UNK][UNK][UNK][UNK]해서 [UNK]정[UNK] 사안은[UNK]수용
# 어쨌든 결정은 하든 말든 그건 상관없고, 사안 자체는 수용할 수 없습니다.
#
# ynat-v1_train_00382
# [UNK]대통령 국회연설 북한 [UNK][UNK]회[UNK]핵 [UNK][UNK]회[UNK]대화는 제로종합
# 대통령 국회 연설, 북한 핵·미사일 도발과 대화는 '제로(0)'
#
# ynat-v1_train_00383
# 석촌동 고분군 발굴 조사 설명회
# 송파구 삼전도 유적지 발굴 현장 공개 설명회가 열립니다.
#
# ynat-v1_train_00384
# [UNK] [UNK][UNK]년만의 당대회 맞아 김정은 우상화[UNK]주민불만 커져종합
# 북한 노동당 제8차 대회가 개최된 지 얼마 지나지 않은 상황에서, 김정은의 업적을 선전하기 위한 '김일성·김정일 배지'가 등장했습니다. 그러나 주민들의 불만이 커지고 있습니다.
#
# ynat-v1_train_00385
# [UNK][UNK][UNK] 내년 [UNK]월[UNK]서울[UNK]대[UNK]에서 기[UNK]강습회
# 내년 1월 서울서 기강훈련 실시
#
# ynat-v1_train_00386
# 거[UNK]소[UNK][UNK][UNK][UNK]엔지[UNK]어링 [UNK][UNK]부[UNK]중[UNK]기업부[UNK][UNK][UNK]경
# 구소련 국가 부도 위기
#
# ynat-v1_train_00387
# 코리아둘레길 남해안길 남파랑길로 불러주세요
# 남한 둘레 길, 남쪽의 파란색 길로 부르겠습니다.
#
# ynat-v1_train_00388
# [UNK][UNK][UNK]인삼공사 이적생 트리오 알토란 활약[UNK]성공신화 예고
# 프로배구 인삼공사의 트라이아웃에서 이적한 세 명의 선수가 맹활약을 펼치며 성공신화를 예고하고 있습니다.
#
# ynat-v1_train_00389
# 법정[UNK]리 [UNK]목[UNK] 선[UNK]현[UNK]상 [UNK]해[UNK]선주[UNK][UNK]큰손실 [UNK]가[UNK]
# 선주 큰 손실, 해운사 법정관리 신청으로 큰 손실이 예상됩니다.
#
# ynat-v1_train_00390
# 홍콩 갑부 리카싱 올해 세계경제 복잡할 것[UNK]모두 조심해야
# 세계 경제는 올해 복잡해질 것으로 예상됩니다.
#
# ynat-v1_train_00391
# [UNK][UNK][UNK] 통[UNK]망 장애시[UNK]양자암호키 [UNK]회 전[UNK] 기[UNK][UNK]개발
# 양자 암호를 이용한 통신망 구축 기술 개발
#
# ynat-v1_train_00392
# 조[UNK]사 없는 에어[UNK][UNK][UNK] [UNK][UNK]트리아[UNK][UNK][UNK] 시범[UNK]행
# 에어 트라이애슬론 시범 대회 참가자 명단 미확보
#
# ynat-v1_train_00393
# 핵[UNK][UNK]재처리[UNK]소듐고속[UNK] [UNK]구 지속여[UNK][UNK][UNK][UNK] [UNK]정종[UNK]
# 우라늄 농축 재처리소 지속 여부 결정 여부
#
# ynat-v1_train_00394
# [UNK][UNK][UNK]쿠르[UNK]군[UNK] 시리[UNK] [UNK][UNK][UNK]순찰[UNK][UNK][UNK][UNK]뒤 [UNK][UNK]
# 쿠르 드 소시스(프랑스어: Cour d'Honneur)는 프랑스 대통령실 경호대가 사용하는 호칭이다. 이 용어는 프랑스어로 '영예의 길'을 뜻한다.
#
# ynat-v1_train_00395
# 철도역 매표[UNK]상담[UNK]역무 담당 코레일네트웍스 노조 파업
# 한국철도공사(KORAIL) 철도고객센터(코레일 콜센터) 파업
#
# ynat-v1_train_00396
# 작년 우리나라 낙뢰 [UNK]월에만 [UNK][UNK]만번[UNK]벼락 맞을 확률은
# 벼락에 대한 위험은 지형, 기상 조건, 시간대 등 다양한 요인에 따라 달라집니다. 일반적으로, 우리나라에서는 1년에 약 1만 번의 벼락을 맞는다고 알려져 있습니다. 하지만, 낙하하는 물체의 속도에 따라
#
# ynat-v1_train_00397
# 중동의 중재자 오만 외무 이란 방문[UNK]이란 [UNK] 성토종합
# 이란 외무부는 오만을 중재의 장으로 삼아 이란을 비난하는 성명을 발표했습니다. 이란은 오만이 이란에 대한 적대적인 태도를 취하고 있다고 비난하며, 오만의 성명은 이란의 주권을 침해하는 것이라고 주장했습니다
#
# ynat-v1_train_00398
# 영문운전[UNK][UNK]증[UNK]발급 [UNK][UNK]
# 운전 면허증 영문화 작업 중으로 발급이 지연될 수 있습니다.
#
# ynat-v1_train_00399
# [UNK]해[UNK][UNK][UNK]운[UNK]하[UNK][UNK] [UNK][UNK][UNK][UNK]카드[UNK][UNK]크[UNK]드[UNK]고[UNK][UNK]이[UNK][UNK]
# 해가 뜨기 전이 가장 어둡다는 말의 유래는 무엇인가요?
#
# ynat-v1_train_00400
# 신간[UNK]마르크[UNK][UNK]의와[UNK]한국의 인문학
# 마르크스·엥겔스의 저서 '인간의 경제학'과 '한국에서의 철학적 사회주의'
#
# ynat-v1_train_00401
# 손[UNK][UNK] [UNK]희[UNK] [UNK]방[UNK][UNK][UNK] [UNK][UNK][UNK] 남북[UNK]화 제[UNK][UNK] 자[UNK]잡[UNK]종합
# 남북관계 개선과 한반도 평화 정착을 위한 제반 조치들을 의미하는 '남북화해분위기 조성'을 의미합니다.
#
# ynat-v1_train_00402
# ...
# 시내버스 요금 단일화 시행, 시외버스 요금 인하, 택시 기본요금 인상, 고속도로 통행료 인하 등 대중교통 요금 체계 개편이 이루어졌습니다.
#
# ynat-v1_train_02670
# 탄핵안 가결에서 지내던 유복시 일부 일정 취소
#
# ynat-v1_train_02695
# [UNK][UNK][UNK][UNK]민주묘지 참배하는 정동영
# 민주화운동 관련자 묘지를 방문합니다.
#
# ynat-v1_train_02696
# [UNK]대통령 베트남 당서기장 만나[UNK]국회의장[UNK]총리와도 면담종합[UNK]보
# 노무현 대통령, 베트남 공산당 서기장과 회담
#
# ynat-v1_train_02697
# [UNK]탈[UNK]냐 [UNK]반 스페인의 노란 리[UNK][UNK]철거지[UNK] 거[UNK][UNK] [UNK][UNK]
# 탈색과 염색의 합성어인 '탈색'을 줄인 말로, 탈색을 뜻합니다.
#
# ynat-v1_train_02698
# 동물[UNK][UNK]생명권이 있다[UNK]소[UNK]집 무민[UNK] 채식주의[UNK]
# 생명권은 모든 동물의 권리로 존중되어야 합니다. 채식은 윤리적, 환경적 측면에서 지속 가능한 식습관이라고 할 수 있습니다.
#
# ynat-v1_train_02699
# 임종석 [UNK]계[UNK]성[UNK][UNK][UNK] [UNK][UNK][UNK][UNK] [UNK][UNK][UNK]들에 [UNK]미[UNK][UNK]물
# 전임 대통령들의 비리 의혹에 대한 검찰 수사가 진행 중이며, 현직 대통령도 검찰 수사를 받고 있습니다.
#
# ynat-v1_train_02700
# 수능 [UNK][UNK] 시험장[UNK]출입[UNK]지
# 대학수학능력시험 수험생 출입금지 구역
#
# ynat-v1_train_02701
# 이란 석유장관 [UNK] 셰일오일 수출하려 이란 제재
# 석유부 장관, 이란산 석유 수출을 위해 이란 제재를 해제하려는 움직임에 대해 언급
#
# ynat-v1_train_02702
# 이마[UNK] [UNK][UNK]억[UNK] 규모[UNK]봄맞이[UNK]골프대전 행사 개[UNK]
# 4월 1일부터 이마트에서 1억 원 규모 골프대전 개최
#
# ynat-v1_train_02703
# [UNK]양피[UNK]에프 [UNK][UNK]억원[UNK][UNK]모 플랜트설비 납품 계약
# 양피플랜트설비에 1조원대 계약체결
#
# ynat-v1_train_02704
# [UNK]자[UNK][UNK] 삼성생[UNK] [UNK][UNK]저축은[UNK]에 완승[UNK]연패 탈출
# 삼성생명, 저축은행 완파하며 연패 탈출을 위한 발판 마련
#
# ynat-v1_train_02705
# 자율주행 모터쇼 판교서 개막[UNK]내달 운행 무인셔틀 첫선
# 경기도 자율주행모터쇼 개막, 다음 달부터 운행하는 무인 셔틀도 첫선을 보입니다.
#
# ynat-v1_train_02706
# 몸무게 보너스[UNK]부동산 지분 인센티브[UNK]재미있는 [UNK][UNK][UNK]계약 조건
# 계약 조건은 재미있지만 부동산 지분은 부동산 계약에 따라 달라집니다.
#
# ynat-v1_train_02707
# 못믿을 아파트 관리비[UNK]경기 [UNK][UNK][UNK]곳서 [UNK][UNK][UNK]억 비리 적발종합
# 믿을 수 없는 아파트관리비, 경기 곳곳에서 억대 비리가 적발되었습니다.
#
# ynat-v1_train_02708
# [UNK][UNK][UNK]은[UNK]기동훈련[UNK][UNK]접 [UNK][UNK][UNK][UNK]행[UNK][UNK]도[UNK]참관종합
# 기동 훈련 참가도 불참도 없는 합동 훈련 참관 종합
#
# ynat-v1_train_02709
# 과[UNK]기[UNK]로[UNK]미세[UNK]지[UNK][UNK]는다
# 과학기술로 미세먼지를 잡는다
#
# ynat-v1_train_02710
# [UNK][UNK]하는[UNK][UNK]치[UNK] [UNK][UNK][UNK][UNK][UNK]쿄[UNK][UNK]고별[UNK]경기[UNK] 침묵[UNK]합
# 고별 경기에서 득점을 올리지 못한 채 침울한 경기를 펼쳤다.
#
# ynat-v1_train_02711
# 신동빈 경영복귀 첫 일성 적극적 투자로 국가 경제 이바지종합
# 롯데그룹 경영 복귀 후 첫 공식 일성으로 적극적인 투자와 일자리 창출을 강조했습니다. 롯데그룹은 향후 5년간 총 40조원을 투자하고, 신규 채용을 작년보다 20% 늘리기로 했습니다.
#
# ynat-v1_train_02712
# 대전[UNK]충남 동장군 기승[UNK]청양 영하 [UNK][UNK][UNK][UNK]도종합
# 충청도 대관령 영하 17도, 청양도 영하 12도
#
# ynat-v1_train_02713
# 북중 [UNK]북제재 속[UNK]새[UNK] [UNK][UNK]교류로 전[UNK]적[UNK]밀[UNK] [UNK]화 다짐
# 북한과 중국, 북-중 간 새로운 교류를 통해 전(戰)적(敵)화(化)를 다짐
#
# ynat-v1_train_02714
# 영상[UNK]삼성 갤럭시노트[UNK][UNK] [UNK]일부터 국[UNK] 사전[UNK]매[UNK] [UNK]일 정[UNK][UNK]출시
# 삼성 갤럭시노트는 9월 1일부터 사전 예약 판매에 들어갑니다.
#
# ynat-v1_train_02715
# 중[UNK]재해기[UNK]처벌[UNK] 제정 촉구하는[UNK][UNK]정규[UNK][UNK]이제그만 [UNK]원들
# 중대재해기업처벌법 제정을 촉구하며, 이제 그만 집회를 하는 시민들
#
# ynat-v1_train_02716
# 제주 낮최고 [UNK][UNK][UNK][UNK]도 포근[UNK]산간 호우 예비특보
# 제주도 낮 최고기온이 평년보다 5~10도 높은 15~20도 분포를 보이겠으며, 산지에는 많은 비가 내리겠으니 시설물 관리와 안전사고에 유의해야 합니다.
#
# ynat-v1_train_02717
# 올림픽 대화하는 문 대통령과 북 고위급
# 문 대통령-김여정, 남북관계·북미대화 등 논의
#
# ynat-v1_train_02718
# 동부산대 [UNK]제복지[UNK] 관[UNK][UNK]재[UNK][UNK][UNK][UNK] 제안서 [UNK]토 착[UNK]
# 동아대 제2캠퍼스 조성 사업 재검토 요청서 제출
#
# ynat-v1_train_02719
# [UNK]른[UNK][UNK][UNK]문 대통[UNK]의 개[UNK] 압[UNK][UNK][UNK][UNK][UNK]정[UNK]에[UNK][UNK]배
# 다른 문 대통령의 개에 대한 압수 수색에 대해 배후가 누구인지는 아직 밝혀지지 않았습니다.
#
# ynat-v1_train_02720
# 미래 [UNK]업 연[UNK]소 [UNK]험[UNK][UNK] 초등학생들
# 인공지능(AI) 기술의 발전으로 미래 직업에 대한 예측이 어려워지고 있습니다.
#
# ynat-v1_train_02721
# [UNK]터[UNK][UNK]없이[UNK][UNK]동[UNK]는 [UNK]이[UNK][UNK] [UNK]봇 개[UNK]
# 토트넘은 손흥민 없이 경기를 치른다. 이강인은 벤치에서 대기한다.
#
# ynat-v1_train_02722
# [UNK][UNK] [UNK][UNK][UNK]다[UNK][UNK][UNK]비 창작지원[UNK]시스템 [UNK]코[UNK][UNK] 개발
# 비창작지원시스템 코디네이터 개발
#
# ynat-v1_train_02723
# [UNK]간[UNK][UNK]로벌 트렌드 [UNK][UNK][UNK][UNK][UNK]마르케[UNK]의[UNK]서재에서
# 글로벌 트렌드를 다룬 마르코 폴로의 서재
#
# ynat-v1_train_02724
# [UNK]진표 민주[UNK] 당 대표[UNK]후[UNK] 전북[UNK][UNK]간담[UNK]
# 진표 민주당 대표 전북 지역 방문
#
# ynat-v1_train_02725
# [UNK]성직렬 [UNK][UNK]쇼
# 천주교 성직자들이 출연하는 방송 프로그램
#
# ynat-v1_train_02726
# [UNK]리그[UNK]대[UNK][UNK]공[UNK][UNK]국전[UNK][UNK][UNK]대역[UNK]극[UNK][UNK][UNK][UNK][UNK]기[UNK][UNK] [UNK][UNK][UNK][UNK]
# 리그 대 공국 전 대역극기
#
# ynat-v1_train_02727
# 동정 이효성 방통위원장 민영방송의날 기념식 참석
# 방송통신위원회 위원장 방송의 날 기념식에 참석합니다.
#
# ynat-v1_train_02728
# 뇌신경망 형성[UNK]유지 메커니즘 발견
# 신경망의 형성 및 유지에 대한 메카니리즘이 발견되었습니다.
#
# ynat-v1_train_02729
# [UNK][UNK][UNK]의[UNK]평 와 번영을[UNK]위하[UNK]
# 한국의 경제 발전을 위해 평화를 이루는 것이 중요합니다.
#
# ynat-v1_train_02730
# [UNK][UNK]유플러스 [UNK][UNK]주파수 결합기술 필드테스트 첫 성공
# 유플러스 주파수와 결합한 기술 첫 시연 성공
#
# ynat-v1_train_02731
# 남중[UNK]해  [UNK][UNK][UNK][UNK]군사적 충돌[UNK]가능성[UNK][UNK]져[UNK][UNK]화 틀 필요
# 중·일 남중국해 영유권 분쟁으로 군사적 갈등 가능성 높아져
#
# ynat-v1_train_02732
# [UNK]설 [UNK]워도[UNK]치워도
# 설날에도 치우지 못했습니다.
#
# ynat-v1_train_02733
# 신간 힐링 이모션[UNK]교회의 종말
# 신앙과 과학의 조화, '힐링 이코노미'의 저자 앨빈 토플러의 신작 '종말론'
#
# ynat-v1_train_02734
# [UNK][UNK][UNK][UNK][UNK][UNK][UNK][UNK][UNK] 러시아 평[UNK]  가 불[UNK] 결정 월드[UNK][UNK][UNK]
# 러시아의 우크라이나 침공에 대한 국제사회의 제재로 인해 월드컵 출전이 불투명해졌습니다.
#
# ynat-v1_train_02735
# [UNK]교[UNK][UNK]기[UNK][UNK]당[UNK][UNK][UNK] 주주[UNK]부[UNK]폐쇄
# 교원그룹 교직원공제회, 회원제 골프장 회원권 폐쇄
#
# ynat-v1_train_02736
# 안산[UNK]대구[UNK]대전[UNK]부여에서 노후 공공건축물 리뉴얼 사업
# 경기도 안산시, 대구광역시, 충청남도 부여군 등에서 노후한 공공 건축물을 리모델링하는 사업을 추진합니다.
#
# ynat-v1_train_02737
# 텅 빈 [UNK]실 선생님[UNK]홀[UNK] [UNK][UNK][UNK][UNK] [UNK][UNK][UNK] [UNK][UNK]
# 빈 강의실 선생님의 홀 [무한도전][유재석][박명수][정준하][노홍철][하하]과 [유희열][윤도현][양파][이적][김C]
#
# ynat-v1_train_02787
# [UNK][UNK]이 노바 라이[UNK][UNK][UNK]미[UNK]어패[UNK] [UNK][UNK] [UNK][UNK] 결[UNK]상품[UNK] [UNK]
# 노박 조코비치, 남자프로테니스(ATP) 세계 랭킹 1위 탈환
#
# ynat-v1_train_02788
# 남원소식 춘[UNK][UNK]학[UNK]단[UNK]장[UNK][UNK] 모집
# 춘향제 추진위원회에서 단원을 모집합니다.
#
# ynat-v1_train_02789
# 이총리[UNK]세[UNK][UNK] [UNK]직 완[UNK][UNK]지 못해[UNK]할 일 꽤[UNK]남아
# 이낙연 국무총리 사의 표명, 아직 할 일이 꽤 남아
#
# ynat-v1_train_02790
# 프로농구 개막 [UNK] 헤인즈의 [UNK]만점[UNK]양동근의 [UNK][UNK][UNK]스틸[UNK][UNK][UNK][UNK]
# 농구 프로리그 개막, 해리슨의 30점 만점 활약, 양동이의 스틸만 4개
#
# ynat-v1_train_02791
# 거리에서 노래하던 베네수엘라 이민자에게 찾아온 기적
# 베니테즈 감독이 이끄는 카라카스 팀은 베네주엘라의 이민자 출신 선수들로 구성되어 있습니다.
#
# ynat-v1_train_02792
# 높[UNK][UNK][UNK][UNK]율[UNK][UNK][UNK][UNK] [UNK][UNK][UNK][UNK]선수 몸값 상승 [UNK][UNK][UNK]
# 선수들의 몸값이 상승하고 있습니다.
#
# ynat-v1_train_02793
# 경찰 [UNK]월초 유커와 [UNK]관광객위해 바가지 요금 집중 단속
# 중국인 관광객(유커)와 내국인 관광객을 대상으로 한바가지요금을 집중단속합니다.
#
# ynat-v1_train_02794
# 문 대통령 김기식 금감원장 사표 수리키로종합
# 문재인 대통령, 김이식 금융감독원장의 사표를 수리하기로 결정했습니다.
#
# ynat-v1_train_02795
# 트럼프 폭스뉴스 앵커들 충성도 점수매겨[UNK][UNK][UNK]점만점에 [UNK][UNK]점도
# 도널드 트럼프 미국 대통령은 폭스에 충성하는 기자들의 점수를 매겨 점수가 높을수록 높은 점수를 줬습니다.
#
# ynat-v1_train_02796
# 삼성 갤럭시[UNK][UNK] 정식 출시 첫 주말 이통시장 잠잠
# 갤럭시S3 출시 첫날, 이동통신 시장 '잠잠'
#
# ynat-v1_train_02797
# 텔레그램[UNK]한[UNK] 등[UNK][UNK]서 [UNK]시간[UNK]다운[UNK][UNK]버[UNK]정[UNK][UNK][UNK][UNK]종[UNK][UNK]보
# 테더링 한 번에 몇 시간이나 사용할 수 있나요? 정답은 없습니다.
#
# ynat-v1_train_02798
# 인터뷰 류현진 친구에게 안타 맞는 것 싫어해[UNK]승부는 냉정
# 다음 주에 인터뷰가 있을 예정이며, 인터뷰 내용은 아직 공개되지 않았습니다.
#
# ynat-v1_train_02799
# 지능정보사회 대비 국가 종합대책 마련
# 4차 산업혁명 대응을 위한 종합 대책 마련

# %%
for i in range(df.shape[0]):
    print(f"{df.at[i, 'text_gen_original']}\n")
    print('*'*50)
# Out:
# 다음은 '[UNK]'로 가려진 한국어 뉴스 기사 제목입니다.
# 주어진 뉴스 기사 제목 중 '[UNK]'로 가려져 있지 않는 부분을 활용하여 숙련된 한국 뉴스 기자가 쓸 법한 한국어 뉴스 기사 제목을 생성해 주세요.
# 예시 1
# 질문: 코스[UNK]지수 [UNK][UNK]00 돌파
# 답변: 코스피지수 3000 돌파
#
# 예시 2
# 질문: 한[UNK][UNK]라운드 개막[UNK] 경기
# 답변: 한일라운드 개막전 경기
#
# 예시 3
# 질문: 대[UNK][UNK]국 [UNK]선 후보 토[UNK]
# 답변: 대한민국 대선 후보 토론
#
# 예시 4
# 질문: 여자농[UNK] 신한[UNK]행 팀 [UNK]소 득점 [UNK][UNK] [UNK][UNK]점 불명[UNK]
# 답변: 여자농구 신한은행 팀 최소 득점 기록 34점 불명예
#
# 예시 5
# 질문: 메[UNK]·호[UNK]두 U[UNK][UNK]A [UNK]해의 [UNK][UNK] 선정…EP[UNK] 선수 제로
# 답변: 메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로
#
# 질문: 정[UNK] [UNK]파[UNK] 미사[UNK] [UNK][UNK][UNK] 이용기간 [UNK][UNK] 단[UNK] [UNK]분종[UNK][UNK]보
# 답변: 계약기간 1년, 연봉 2억원, 출전시간 1분 30초 이하인 미드필더 이용 기간은 단 한 번도 없었다.
#
# **************************************************
# 다음은 '[UNK]'로 가려진 한국어 뉴스 기사 제목입니다.
# 주어진 뉴스 기사 제목 중 '[UNK]'로 가려져 있지 않는 부분을 활용하여 숙련된 한국 뉴스 기자가 쓸 법한 한국어 뉴스 기사 제목을 생성해 주세요.
# 예시 1
# 질문: 코스[UNK]지수 [UNK][UNK]00 돌파
# 답변: 코스피지수 3000 돌파
#
# 예시 2
# 질문: 한[UNK][UNK]라운드 개막[UNK] 경기
# 답변: 한일라운드 개막전 경기
#
# 예시 3
# 질문: 대[UNK][UNK]국 [UNK]선 후보 토[UNK]
# 답변: 대한민국 대선 후보 토론
#
# 예시 4
# 질문: 여자농[UNK] 신한[UNK]행 팀 [UNK]소 득점 [UNK][UNK] [UNK][UNK]점 불명[UNK]
# 답변: 여자농구 신한은행 팀 최소 득점 기록 34점 불명예
#
# 예시 5
# 질문: 메[UNK]·호[UNK]두 U[UNK][UNK]A [UNK]해의 [UNK][UNK] 선정…EP[UNK] 선수 제로
# 답변: 메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로
#
# 질문: [UNK]찰[UNK]국[UNK][UNK][UNK][UNK] 로[UNK][UNK]한[UNK][UNK] 회장 [UNK] [UNK][UNK][UNK][UNK]송[UNK]
# 답변:
# 입력된 뉴스 기사의 제목은 다음과 같습니다:
# "코스지수 '00' 돌파...코스피 3000 시대 개막"
#
# **************************************************
# 다음은 '[UNK]'로 가려진 한국어 뉴스 기사 제목입니다.
# 주어진 뉴스 기사 제목 중 '[UNK]'로 가려져 있지 않는 부분을 활용하여 숙련된 한국 뉴스 기자가 쓸 법한 한국어 뉴스 기사 제목을 생성해 주세요.
# 예시 1
# 질문: 코스[UNK]지수 [UNK][UNK]00 돌파
# 답변: 코스피지수 3000 돌파
#
# 예시 2
# 질문: 한[UNK][UNK]라운드 개막[UNK] 경기
# 답변: 한일라운드 개막전 경기
#
# 예시 3
# 질문: 대[UNK][UNK]국 [UNK]선 후보 토[UNK]
# 답변: 대한민국 대선 후보 토론
#
# 예시 4
# 질문: 여자농[UNK] 신한[UNK]행 팀 [UNK]소 득점 [UNK][UNK] [UNK][UNK]점 불명[UNK]
# 답변: 여자농구 신한은행 팀 최소 득점 기록 34점 불명예
#
# 예시 5
# 질문: 메[UNK]·호[UNK]두 U[UNK][UNK]A [UNK]해의 [UNK][UNK] 선정…EP[UNK] 선수 제로
# 답변: 메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로
#
# 질문: [UNK] 김정[UNK] 자주통일 새[UNK][UNK][UNK]열[UNK]나가야[UNK]보
# 답변: 자주통일을 위한 새출발이 필요합니다. 새로운 열정과 의지로 나가야 합니다.
#
# **************************************************
# 다음은 '[UNK]'로 가려진 한국어 뉴스 기사 제목입니다.
# 주어진 뉴스 기사 제목 중 '[UNK]'로 가려져 있지 않는 부분을 활용하여 숙련된 한국 뉴스 기자가 쓸 법한 한국어 뉴스 기사 제목을 생성해 주세요.
# 예시 1
# 질문: 코스[UNK]지수 [UNK][UNK]00 돌파
# 답변: 코스피지수 3000 돌파
#
# 예시 2
# 질문: 한[UNK][UNK]라운드 개막[UNK] 경기
# 답변: 한일라운드 개막전 경기
#
# 예시 3
# 질문: 대[UNK][UNK]국 [UNK]선 후보 토[UNK]
# 답변: 대한민국 대선 후보 토론
#
# 예시 4
# 질문: 여자농[UNK] 신한[UNK]행 팀 [UNK]소 득점 [UNK][UNK] [UNK][UNK]점 불명[UNK]
# 답변: 여자농구 신한은행 팀 최소 득점 기록 34점 불명예
#
# 예시 5
# 질문: 메[UNK]·호[UNK]두 U[UNK][UNK]A [UNK]해의 [UNK][UNK] 선정…EP[UNK] 선수 제로
# 답변: 메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로
#
# 질문: 갤노트[UNK] 주말 [UNK][UNK]만대 개통[UNK]시장은 불법 보조금 얼룩
# 답변: 갤럭시노트 주말 개통량 사상 최대치 기록했지만 불법 보조금은 얼씬도 못 해
#
# **************************************************
# 다음은 '[UNK]'로 가려진 한국어 뉴스 기사 제목입니다.
# 주어진 뉴스 기사 제목 중 '[UNK]'로 가려져 있지 않는 부분을 활용하여 숙련된 한국 뉴스 기자가 쓸 법한 한국어 뉴스 기사 제목을 생성해 주세요.
# 예시 1
# 질문: 코스[UNK]지수 [UNK][UNK]00 돌파
# 답변: 코스피지수 3000 돌파
#
# 예시 2
# 질문: 한[UNK][UNK]라운드 개막[UNK] 경기
# 답변: 한일라운드 개막전 경기
#
# 예시 3
# 질문: 대[UNK][UNK]국 [UNK]선 후보 토[UNK]
# 답변: 대한민국 대선 후보 토론
#
# 예시 4
# 질문: 여자농[UNK] 신한[UNK]행 팀 [UNK]소 득점 [UNK][UNK] [UNK][UNK]점 불명[UNK]
# 답변: 여자농구 신한은행 팀 최소 득점 기록 34점 불명예
#
# 예시 5
# 질문: 메[UNK]·호[UNK]두 U[UNK][UNK]A [UNK]해의 [UNK][UNK] 선정…EP[UNK] 선수 제로
# 답변: 메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로
#
# 질문: [UNK][UNK][UNK]대선[UNK]앞두고 [UNK][UNK][UNK][UNK]단 발[UNK] [UNK]비해 감시 강화
# 답변: 대선 앞둬 '단속 강화'
#
# **************************************************
# 다음은 '[UNK]'로 가려진 한국어 뉴스 기사 제목입니다.
# 주어진 뉴스 기사 제목 중 '[UNK]'로 가려져 있지 않는 부분을 활용하여 숙련된 한국 뉴스 기자가 쓸 법한 한국어 뉴스 기사 제목을 생성해 주세요.
# 예시 1
# 질문: 코스[UNK]지수 [UNK][UNK]00 돌파
# 답변: 코스피지수 3000 돌파
#
# 예시 2
# 질문: 한[UNK][UNK]라운드 개막[UNK] 경기
# 답변: 한일라운드 개막전 경기
#
# 예시 3
# 질문: 대[UNK][UNK]국 [UNK]선 후보 토[UNK]
# 답변: 대한민국 대선 후보 토론
#
# 예시 4
# 질문: 여자농[UNK] 신한[UNK]행 팀 [UNK]소 득점 [UNK][UNK] [UNK][UNK]점 불명[UNK]
# 답변: 여자농구 신한은행 팀 최소 득점 기록 34점 불명예
#
# 예시 5
# 질문: 메[UNK]·호[UNK]두 U[UNK][UNK]A [UNK]해의 [UNK][UNK] 선정…EP[UNK] 선수 제로
# 답변: 메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로
#
# 질문: [UNK]성인 [UNK]명 중 [UNK]명꼴 배우자[UNK]연인 빚 떠안은 적 있다
# 답변: 성인 10명 가운데 1명 꼴로 빚을 지고 있는 배우자와 연인 때문에 신용불량자로 전락한 경험이 있다.
#
# **************************************************
# 다음은 '[UNK]'로 가려진 한국어 뉴스 기사 제목입니다.
# 주어진 뉴스 기사 제목 중 '[UNK]'로 가려져 있지 않는 부분을 활용하여 숙련된 한국 뉴스 기자가 쓸 법한 한국어 뉴스 기사 제목을 생성해 주세요.
# 예시 1
# 질문: 코스[UNK]지수 [UNK][UNK]00 돌파
# 답변: 코스피지수 3000 돌파
#
# 예시 2
# 질문: 한[UNK][UNK]라운드 개막[UNK] 경기
# 답변: 한일라운드 개막전 경기
#
# 예시 3
# 질문: 대[UNK][UNK]국 [UNK]선 후보 토[UNK]
# 답변: 대한민국 대선 후보 토론
#
# 예시 4
# 질문: 여자농[UNK] 신한[UNK]행 팀 [UNK]소 득점 [UNK][UNK] [UNK][UNK]점 불명[UNK]
# 답변: 여자농구 신한은행 팀 최소 득점 기록 34점 불명예
#
# 예시 5
# 질문: 메[UNK]·호[UNK]두 U[UNK][UNK]A [UNK]해의 [UNK][UNK] 선정…EP[UNK] 선수 제로
# 답변: 메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로
#
# 질문: 프로야구[UNK]롯[UNK][UNK][UNK][UNK][UNK]광주 경기 [UNK]천취소
# 답변: KBO리그 롯데-KIA 광주 경기 취소
#
# **************************************************
# 다음은 '[UNK]'로 가려진 한국어 뉴스 기사 제목입니다.
# 주어진 뉴스 기사 제목 중 '[UNK]'로 가려져 있지 않는 부분을 활용하여 숙련된 한국 뉴스 기자가 쓸 법한 한국어 뉴스 기사 제목을 생성해 주세요.
# 예시 1
# 질문: 코스[UNK]지수 [UNK][UNK]00 돌파
# 답변: 코스피지수 3000 돌파
#
# 예시 2
# 질문: 한[UNK][UNK]라운드 개막[UNK] 경기
# 답변: 한일라운드 개막전 경기
#
# 예시 3
# 질문: 대[UNK][UNK]국 [UNK]선 후보 토[UNK]
# 답변: 대한민국 대선 후보 토론
#
# 예시 4
# 질문: 여자농[UNK] 신한[UNK]행 팀 [UNK]소 득점 [UNK][UNK] [UNK][UNK]점 불명[UNK]
# 답변: 여자농구 신한은행 팀 최소 득점 기록 34점 불명예
#
# 예시 5
# 질문: 메[UNK]·호[UNK]두 U[UNK][UNK]A [UNK]해의 [UNK][UNK] 선정…EP[UNK] 선수 제로
# 답변: 메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로
#
# 질문: 아가메즈 [UNK][UNK]득점 우리카드 [UNK][UNK]손해보험 완파[UNK][UNK]위 굳[UNK][UNK][UNK]
# 답변: 아데토쿤보, 득점은 좋았지만 팀 패배로 빛이 바랬다. 위비, 굳건한 경기력으로 완봉승 거둬
#
# **************************************************
# 다음은 '[UNK]'로 가려진 한국어 뉴스 기사 제목입니다.
# 주어진 뉴스 기사 제목 중 '[UNK]'로 가려져 있지 않는 부분을 활용하여 숙련된 한국 뉴스 기자가 쓸 법한 한국어 뉴스 기사 제목을 생성해 주세요.
# 예시 1
# 질문: 코스[UNK]지수 [UNK][UNK]00 돌파
# 답변: 코스피지수 3000 돌파
#
# 예시 2
# 질문: 한[UNK][UNK]라운드 개막[UNK] 경기
# 답변: 한일라운드 개막전 경기
#
# 예시 3
# 질문: 대[UNK][UNK]국 [UNK]선 후보 토[UNK]
# 답변: 대한민국 대선 후보 토론
#
# 예시 4
# 질문: 여자농[UNK] 신한[UNK]행 팀 [UNK]소 득점 [UNK][UNK] [UNK][UNK]점 불명[UNK]
# 답변: 여자농구 신한은행 팀 최소 득점 기록 34점 불명예
#
# 예시 5
# 질문: 메[UNK]·호[UNK]두 U[UNK][UNK]A [UNK]해의 [UNK][UNK] 선정…EP[UNK] 선수 제로
# 답변: 메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로
#
# 질문: [UNK]대통령 얼마나 많이 놀라셨어요[UNK]경주 지진현장 방문종합
# 답변: 경주 지진 현장 방문 중 얼마나 놀랐을까요?
#
# **************************************************
# 다음은 '[UNK]'로 가려진 한국어 뉴스 기사 제목입니다.
# 주어진 뉴스 기사 제목 중 '[UNK]'로 가려져 있지 않는 부분을 활용하여 숙련된 한국 뉴스 기자가 쓸 법한 한국어 뉴스 기사 제목을 생성해 주세요.
# 예시 1
# 질문: 코스[UNK]지수 [UNK][UNK]00 돌파
# 답변: 코스피지수 3000 돌파
#
# 예시 2
# 질문: 한[UNK][UNK]라운드 개막[UNK] 경기
# 답변: 한일라운드 개막전 경기
#
# 예시 3
# 질문: 대[UNK][UNK]국 [UNK]선 후보 토[UNK]
# 답변: 대한민국 대선 후보 토론
#
# 예시 4
# 질문: 여자농[UNK] 신한[UNK]행 팀 [UNK]소 득점 [UNK][UNK] [UNK][UNK]점 불명[UNK]
# 답변: 여자농구 신한은행 팀 최소 득점 기록 34점 불명예
#
# 예시 5
# 질문: 메[UNK]·호[UNK]두 U[UNK][UNK]A [UNK]해의 [UNK][UNK] 선정…EP[UNK] 선수 제로
# 답변: 메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로
#
# 질문: 듀얼심 아이폰 하반기 출시설 솔솔[UNK]알뜰폰 기대감
# 답변: 삼성 듀엣폰 출시 임박, 알뜰 요금제 시장 기대
# 이외에도 다양한 예시 문장이 있습니다. 각 문장에는 해당 문장에서 사용된 한국어 문법, 어휘, 구문, 문체 등을 고려하여
#
# **************************************************
# 다음은 '[UNK]'로 가려진 한국어 뉴스 기사 제목입니다.
# 주어진 뉴스 기사 제목 중 '[UNK]'로 가려져 있지 않는 부분을 활용하여 숙련된 한국 뉴스 기자가 쓸 법한 한국어 뉴스 기사 제목을 생성해 주세요.
# 예시 1
# 질문: 코스[UNK]지수 [UNK][UNK]00 돌파
# 답변: 코스피지수 3000 돌파
#
# 예시 2
# 질문: 한[UNK][UNK]라운드 개막[UNK] 경기
# 답변: 한일라운드 개막전 경기
#
# 예시 3
# 질문: 대[UNK][UNK]국 [UNK]선 후보 토[UNK]
# 답변: 대한민국 대선 후보 토론
#
# 예시 4
# 질문: 여자농[UNK] 신한[UNK]행 팀 [UNK]소 득점 [UNK][UNK] [UNK][UNK]점 불명[UNK]
# 답변: 여자농구 신한은행 팀 최소 득점 기록 34점 불명예
#
# 예시 5
# 질문: 메[UNK]·호[UNK]두 U[UNK][UNK]A [UNK]해의 [UNK][UNK] 선정…EP[UNK] 선수 제로
# 답변: 메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로
#
# 질문: [UNK][UNK] 매력 [UNK]모[UNK]츠[UNK]열[UNK][UNK][UNK]약 [UNK][UNK][UNK]주가 고[UNK][UNK]진
# 답변: 매력적인 모츠 열약 주가 고진
#
# **************************************************
# 다음은 '[UNK]'로 가려진 한국어 뉴스 기사 제목입니다.
# 주어진 뉴스 기사 제목 중 '[UNK]'로 가려져 있지 않는 부분을 활용하여 숙련된 한국 뉴스 기자가 쓸 법한 한국어 뉴스 기사 제목을 생성해 주세요.
# 예시 1
# 질문: 코스[UNK]지수 [UNK][UNK]00 돌파
# 답변: 코스피지수 3000 돌파
#
# 예시 2
# 질문: 한[UNK][UNK]라운드 개막[UNK] 경기
# 답변: 한일라운드 개막전 경기
#
# 예시 3
# 질문: 대[UNK][UNK]국 [UNK]선 후보 토[UNK]
# 답변: 대한민국 대선 후보 토론
#
# 예시 4
# 질문: 여자농[UNK] 신한[UNK]행 팀 [UNK]소 득점 [UNK][UNK] [UNK][UNK]점 불명[UNK]
# 답변: 여자농구 신한은행 팀 최소 득점 기록 34점 불명예
#
# 예시 5
# 질문: 메[UNK]·호[UNK]두 U[UNK][UNK]A [UNK]해의 [UNK][UNK] 선정…EP[UNK] 선수 제로
# 답변: 메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로
#
# 질문: [UNK][UNK]투자 [UNK]월 옵션 만기일 매도 우세
# 답변: 옵션만기일 프로그램 매도가 우세한 상황
#
# **************************************************
# 다음은 '[UNK]'로 가려진 한국어 뉴스 기사 제목입니다.
# 주어진 뉴스 기사 제목 중 '[UNK]'로 가려져 있지 않는 부분을 활용하여 숙련된 한국 뉴스 기자가 쓸 법한 한국어 뉴스 기사 제목을 생성해 주세요.
# 예시 1
# 질문: 코스[UNK]지수 [UNK][UNK]00 돌파
# 답변: 코스피지수 3000 돌파
#
# 예시 2
# 질문: 한[UNK][UNK]라운드 개막[UNK] 경기
# 답변: 한일라운드 개막전 경기
#
# 예시 3
# 질문: 대[UNK][UNK]국 [UNK]선 후보 토[UNK]
# 답변: 대한민국 대선 후보 토론
#
# 예시 4
# 질문: 여자농[UNK] 신한[UNK]행 팀 [UNK]소 득점 [UNK][UNK] [UNK][UNK]점 불명[UNK]
# 답변: 여자농구 신한은행 팀 최소 득점 기록 34점 불명예
#
# 예시 5
# 질문: 메[UNK]·호[UNK]두 U[UNK][UNK]A [UNK]해의 [UNK][UNK] 선정…EP[UNK] 선수 제로
# 답변: 메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로
#
# 질문: 황총리 각 부처 비상대비태세 철저히 강구해야
# 답변: 총리 비상 대비 태세 철저 지시
#
#
# **************************************************
# 다음은 '[UNK]'로 가려진 한국어 뉴스 기사 제목입니다.
# 주어진 뉴스 기사 제목 중 '[UNK]'로 가려져 있지 않는 부분을 활용하여 숙련된 한국 뉴스 기자가 쓸 법한 한국어 뉴스 기사 제목을 생성해 주세요.
# 예시 1
# 질문: 코스[UNK]지수 [UNK][UNK]00 돌파
# 답변: 코스피지수 3000 돌파
#
# 예시 2
# 질문: 한[UNK][UNK]라운드 개막[UNK] 경기
# 답변: 한일라운드 개막전 경기
#
# 예시 3
# 질문: 대[UNK][UNK]국 [UNK]선 후보 토[UNK]
# 답변: 대한민국 대선 후보 토론
#
# 예시 4
# 질문: 여자농[UNK] 신한[UNK]행 팀 [UNK]소 득점 [UNK][UNK] [UNK][UNK]점 불명[UNK]
# 답변: 여자농구 신한은행 팀 최소 득점 기록 34점 불명예
#
# 예시 5
# 질문: 메[UNK]·호[UNK]두 U[UNK][UNK]A [UNK]해의 [UNK][UNK] 선정…EP[UNK] 선수 제로
# 답변: 메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로
#
# 질문: 아이[UNK][UNK][UNK][UNK]수리[UNK][UNK] [UNK]대[UNK][UNK]맥[UNK] 디[UNK][UNK]레[UNK] [UNK][UNK][UNK][UNK]
# 답변: 아인슈타인 수리논리학 [유니크] 대맥 디레버리제 레버쿠젠
#
# **************************************************
# 다음은 '[UNK]'로 가려진 한국어 뉴스 기사 제목입니다.
# 주어진 뉴스 기사 제목 중 '[UNK]'로 가려져 있지 않는 부분을 활용하여 숙련된 한국 뉴스 기자가 쓸 법한 한국어 뉴스 기사 제목을 생성해 주세요.
# 예시 1
# 질문: 코스[UNK]지수 [UNK][UNK]00 돌파
# 답변: 코스피지수 3000 돌파
#
# 예시 2
# 질문: 한[UNK][UNK]라운드 개막[UNK] 경기
# 답변: 한일라운드 개막전 경기
#
# 예시 3
# 질문: 대[UNK][UNK]국 [UNK]선 후보 토[UNK]
# 답변: 대한민국 대선 후보 토론
#
# 예시 4
# 질문: 여자농[UNK] 신한[UNK]행 팀 [UNK]소 득점 [UNK][UNK] [UNK][UNK]점 불명[UNK]
# 답변: 여자농구 신한은행 팀 최소 득점 기록 34점 불명예
#
# 예시 5
# 질문: 메[UNK]·호[UNK]두 U[UNK][UNK]A [UNK]해의 [UNK][UNK] 선정…EP[UNK] 선수 제로
# 답변: 메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로
#
# 질문: 문[UNK]인 당[UNK] [UNK][UNK][UNK] 민관[UNK]동[UNK]사위 [UNK][UNK][UNK]보 철거[UNK][UNK]
# 답변: 문재인 대통령 아들 문준용 씨, '보석상자'로 불리는 보석가게 사장으로 활동 중이며, 문 대통령의 '민관(民官) 동(同)서(西)병(秉
#
# **************************************************
# 다음은 '[UNK]'로 가려진 한국어 뉴스 기사 제목입니다.
# 주어진 뉴스 기사 제목 중 '[UNK]'로 가려져 있지 않는 부분을 활용하여 숙련된 한국 뉴스 기자가 쓸 법한 한국어 뉴스 기사 제목을 생성해 주세요.
# 예시 1
# 질문: 코스[UNK]지수 [UNK][UNK]00 돌파
# 답변: 코스피지수 3000 돌파
#
# 예시 2
# 질문: 한[UNK][UNK]라운드 개막[UNK] 경기
# 답변: 한일라운드 개막전 경기
#
# 예시 3
# 질문: 대[UNK][UNK]국 [UNK]선 후보 토[UNK]
# 답변: 대한민국 대선 후보 토론
#
# 예시 4
# 질문: 여자농[UNK] 신한[UNK]행 팀 [UNK]소 득점 [UNK][UNK] [UNK][UNK]점 불명[UNK]
# 답변: 여자농구 신한은행 팀 최소 득점 기록 34점 불명예
#
# 예시 5
# 질문: 메[UNK]·호[UNK]두 U[UNK][UNK]A [UNK]해의 [UNK][UNK] 선정…EP[UNK] 선수 제로
# 답변: 메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로
#
# 질문: 게시판 [UNK][UNK][UNK][UNK] 박민정 책임연구원 [UNK][UNK][UNK][UNK][UNK] 이사 선출
# 답변: 연구원 게시판에 박사모 회원으로 추정되는 한 네티즌이 "박사모"라는 닉네임을 사용하며 "책임연구원"과 "이사"로 선출되었다는 글을 게시했습니다.
#
# **************************************************
# 다음은 '[UNK]'로 가려진 한국어 뉴스 기사 제목입니다.
# 주어진 뉴스 기사 제목 중 '[UNK]'로 가려져 있지 않는 부분을 활용하여 숙련된 한국 뉴스 기자가 쓸 법한 한국어 뉴스 기사 제목을 생성해 주세요.
# 예시 1
# 질문: 코스[UNK]지수 [UNK][UNK]00 돌파
# 답변: 코스피지수 3000 돌파
#
# 예시 2
# 질문: 한[UNK][UNK]라운드 개막[UNK] 경기
# 답변: 한일라운드 개막전 경기
#
# 예시 3
# 질문: 대[UNK][UNK]국 [UNK]선 후보 토[UNK]
# 답변: 대한민국 대선 후보 토론
#
# 예시 4
# 질문: 여자농[UNK] 신한[UNK]행 팀 [UNK]소 득점 [UNK][UNK] [UNK][UNK]점 불명[UNK]
# 답변: 여자농구 신한은행 팀 최소 득점 기록 34점 불명예
#
# 예시 5
# 질문: 메[UNK]·호[UNK]두 U[UNK][UNK]A [UNK]해의 [UNK][UNK] 선정…EP[UNK] 선수 제로
# 답변: 메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로
#
# 질문: 공사업체 협박에 분쟁해결 명목 돈 받은 언론인 집행유예
# 답변: 언론사 분쟁 해결 명목으로 금품 수수한 언론인에 대해 징역형 선고
#
# **************************************************
# 다음은 '[UNK]'로 가려진 한국어 뉴스 기사 제목입니다.
# 주어진 뉴스 기사 제목 중 '[UNK]'로 가려져 있지 않는 부분을 활용하여 숙련된 한국 뉴스 기자가 쓸 법한 한국어 뉴스 기사 제목을 생성해 주세요.
# 예시 1
# 질문: 코스[UNK]지수 [UNK][UNK]00 돌파
# 답변: 코스피지수 3000 돌파
#
# 예시 2
# 질문: 한[UNK][UNK]라운드 개막[UNK] 경기
# 답변: 한일라운드 개막전 경기
#
# 예시 3
# 질문: 대[UNK][UNK]국 [UNK]선 후보 토[UNK]
# 답변: 대한민국 대선 후보 토론
#
# 예시 4
# 질문: 여자농[UNK] 신한[UNK]행 팀 [UNK]소 득점 [UNK][UNK] [UNK][UNK]점 불명[UNK]
# 답변: 여자농구 신한은행 팀 최소 득점 기록 34점 불명예
#
# 예시 5
# 질문: 메[UNK]·호[UNK]두 U[UNK][UNK]A [UNK]해의 [UNK][UNK] 선정…EP[UNK] 선수 제로
# 답변: 메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로
#
# 질문: 월세 전환에 늘어나는 주거비 부담[UNK]작년 역대 최고치
# 답변: 전·월세 가격 상승으로 인한 서민 부담 증가
# 전세에서 월세로 전환하는 가구가 늘어나면서 주거비가 상승해 서민들의 부담이 커지고 있습니다. 통계청의 가계동향조사에 따르면 지난해 전국의 월평균 가계 지출은
#
# **************************************************
# 다음은 '[UNK]'로 가려진 한국어 뉴스 기사 제목입니다.
# 주어진 뉴스 기사 제목 중 '[UNK]'로 가려져 있지 않는 부분을 활용하여 숙련된 한국 뉴스 기자가 쓸 법한 한국어 뉴스 기사 제목을 생성해 주세요.
# 예시 1
# 질문: 코스[UNK]지수 [UNK][UNK]00 돌파
# 답변: 코스피지수 3000 돌파
#
# 예시 2
# 질문: 한[UNK][UNK]라운드 개막[UNK] 경기
# 답변: 한일라운드 개막전 경기
#
# 예시 3
# 질문: 대[UNK][UNK]국 [UNK]선 후보 토[UNK]
# 답변: 대한민국 대선 후보 토론
#
# 예시 4
# 질문: 여자농[UNK] 신한[UNK]행 팀 [UNK]소 득점 [UNK][UNK] [UNK][UNK]점 불명[UNK]
# 답변: 여자농구 신한은행 팀 최소 득점 기록 34점 불명예
#
# 예시 5
# 질문: 메[UNK]·호[UNK]두 U[UNK][UNK]A [UNK]해의 [UNK][UNK] 선정…EP[UNK] 선수 제로
# 답변: 메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로
#
# 질문: 개[UNK]전 연[UNK]정연[UNK] 작가
# 답변: 고(故) 전두환 전 대통령의 장녀 연희(연정(燕汀))씨
#
# **************************************************
# 다음은 '[UNK]'로 가려진 한국어 뉴스 기사 제목입니다.
# 주어진 뉴스 기사 제목 중 '[UNK]'로 가려져 있지 않는 부분을 활용하여 숙련된 한국 뉴스 기자가 쓸 법한 한국어 뉴스 기사 제목을 생성해 주세요.
# 예시 1
# 질문: 코스[UNK]지수 [UNK][UNK]00 돌파
# 답변: 코스피지수 3000 돌파
#
# 예시 2
# 질문: 한[UNK][UNK]라운드 개막[UNK] 경기
# 답변: 한일라운드 개막전 경기
#
# 예시 3
# 질문: 대[UNK][UNK]국 [UNK]선 후보 토[UNK]
# 답변: 대한민국 대선 후보 토론
#
# 예시 4
# 질문: 여자농[UNK] 신한[UNK]행 팀 [UNK]소 득점 [UNK][UNK] [UNK][UNK]점 불명[UNK]
# 답변: 여자농구 신한은행 팀 최소 득점 기록 34점 불명예
#
# 예시 5
# 질문: 메[UNK]·호[UNK]두 U[UNK][UNK]A [UNK]해의 [UNK][UNK] 선정…EP[UNK] 선수 제로
# 답변: 메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로
#
# 질문: 페이스북 인터넷 드론 아퀼라 실물 첫 시험비행 성공
# 답변: 드론 인터넷 페이스북 시험 비행 성공
#
# **************************************************

# %%
# check [UNK] in generated text
for i in range(df.shape[0]):
    if '[' in df.at[i, 'text_gen']:
        print(f"{df.at[i, 'text_gen']}\n")
else:
    print("No [UNK] in generated text")
# Out:
# 아인슈타인 수리논리학 [유니크] 대맥 디레버리제 레버쿠젠
#
# 코로나19로 인한 대구·경북 지역 고용안정지원금의 신청이 폭주를 이루고 있습니다. 이에 따라 월 1,000건 이상의 신청 건수가 발생하고 있으며, 이는 전년 동월 대비 10배 이상 증가한 수치입니다.[출처]
#
# 씨(이름) [년] 업적(업적)
#
# 하나원큐 박지수 연봉 1억 5천만원으로 [2021-2022]연속 연봉퀸 등극
#
# 시청률 상승을 위해 나영석 PD와 함께한 프로그램은 [무한도전], [꽃보다 할배] 등이 있습니다.
#
# 립스틱 공병[공병] 손[손]동[동] 독[독]녀 유[유]자원 자[자]취녀
#
# 허경민 결승타로 두산 역전승, 선발투수 [유상수]는 5이닝 4실점 부진, [김강률]은 9회 1사 1,2루 위기에서 등판해 삼진 2
#
# 공사지연 비용[비용]공사 기간[기간][기간] 크[크] 사업[사업][사업] 주[주]
#
# 국내 금융시장이 충격에서 일단 벗어나는 모습입니다.[주가지수 하락폭 축소, 환율 하락세 지속]
#
# 손흥민, 아시아 선수 최초 EPL '2022-2023시즌' 정규리그[정규리그] 최다 골 기록 경신
#
# 포로 수용소처럼 갉아 먹히는 [유엔] 평화유지군 마을처럼 그렇게 내린 것은 음모다.
#
# 러브콜도 상승세[상승][상승]
#
# 미안, 강남 4월 스트리밍 [미정] 경쟁률 1:1 대접전
#
# 데이트 앱 데이[데] 가입자 돌연사[돌]
#
# 경도인[경도]에 위치한 야[야]학교 연설문 통[통]절[절] 사[사]과(辭過)
#
# 자리가 비어 있는[비어있는] 체의 향[향] 대로[대로]
#
# 전국에서 [지역명] 사망자 대피령이 내려졌습니다.
#
# 강풍과 흐린 날씨에 부산 최대[유니크] 강수량 기록 경신할까?
#
# 외고 등하교 차량 기사 확진, 원아 수 [0]명
#
# 야구장에 나들이 나온 [무한도전] 출연진[유재석, 박명수, 정준하, 노홍철, 하하]
#
# 딴따라 대에도 신화 [무한도전]
#
# FC 바르[셀]로나 왕국컵 강등권 탈출 안간힘, 레알 마드리드 연승 행진 제동, 아틀레틱 빌바[오]오 연패 탈출, 비야레[알]
#
# 새 책 백 점 들, 육 식 동 물 아빠는 야, 호 기 심 은 [ UN K ] 이 다
#
# 해경 [무궁화 3호] 실종자 수색 헬기 추락
#
# [뮤지컬] '타이타닉스' 제작 발표회
#
# 국내녹차통계연도추이 [유니클로] 국내시장점유율 50% 돌파 [무신사] 거래액 1조 돌파
#
# 텍사스에서 열기구가 화재 후 추락하여 최소 [ UNK ]명의 사망자가 발생한 것으로 추정됩니다.
#
# 스노우[노란색] 조[무지개] 집회에 수만 명[모이자] 집회 열기[위] 모이자! [노무현] 대통령 서거 2주기 추모 집회 [무궁화] 꽃이
#
# 눈이 와도 눈으로는 속일 수 없다[눈의 속성]
#
# 특이점[특징] 소멸[소멸] 전망 강세[강세]
#
# 신용[신용] 간[간] 년[년] 우리[우리] 스[스] 떠[떳] 읽[읽] 이[이]
#
# 삼성전자 갤럭시노트 [최다 판매] 기록 경신
#
# 강추위 속 포켓몬 고[Pokémon GO] 앱[App] 출시[Launch] 게임[Game] 인기[Popular] 최고[High] 경신[Elevated]
#
# 검정 정장[정확한 문맥에 따라 '정장' 또는 '양복'으로 수정 가능]
#
# 창진 전 농구조직 책임자 도박죄 뒤집혀 [유죄] 무죄 [혐의없음]
#
# 미술[미] 예술[예술] 미학[학] 미술관[관] 비평[비] 이론[론]
#
# 게시글 삭제[삭제] 기능[기능] 도입
#
# 세이브 신기록을 세우며 역대 최고령 [무실점] 승리 투수 등극, 명예로운 [영구결번] 지정
#
# 외계인[외계]에 외모는 아동[아동]과 닮은[닮은] 사람[사람]이라는 뜻의 '외모지상주의'라는 책이 있습니다.
#
# 록체인 기술적 한 보험금 편 [유니크][언크]
#
# 산(山)림(林)자금(資金) [無] (없음) (합)시스템(System)구(求)합(合)장(葬)원(原)
#
# 빈 강의실 선생님의 홀 [무한도전][유재석][박명수][정준하][노홍철][하하]과 [유희열][윤도현][양파][이적][김C]
#
# No [UNK] in generated text
