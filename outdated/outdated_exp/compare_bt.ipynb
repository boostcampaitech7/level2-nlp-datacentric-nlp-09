# %%
import pandas as pd
import re

raw = pd.read_csv('../../data/preprocessed_v2/Tnoise_1073.csv')
bt = pd.read_csv('../../data/preprocessed_v2/Tnoise_BT_1073.csv')
result = raw.copy()

# korean ratio
raw['kr_ratio'] = raw['text'].apply(lambda x: len(re.findall('[가-힣]', x)) / len(x))
# sort

bt['kr_ratio'] = bt['text'].apply(
    lambda x: len(re.findall('[가-힣]', x)) / len(x) if isinstance(x, str) and len(x) > 0 else 0
)

# compare the ratio
for i in range(len(raw)):
    if raw.at[i, 'kr_ratio'] < bt.at[i, 'kr_ratio']:
        result.at[i, 'text'] = bt.at[i, 'text']
    else:
        result.at[i, 'text'] = raw.at[i, 'text']
result

result.to_csv('../../data/preprocessed_v2/Tnoise_comp_1073.csv', index=False)

# %%
# Out:
#                        ID                                         text  target
# 0     ynat-v1_train_00000             정i :파1 미사z KT( 이용기간 2e 단] Q분종U2보       4
# 1     ynat-v1_train_00002                       m 김정) 자주통일 새,?r열1나가야1보       2
# 2     ynat-v1_train_00004                 pI美대선I앞두고 R2fr단 발] $비해 감시 강화       6
# 3     ynat-v1_train_00006                      KBO~롯데 자이언츠 광주 경기 예천 취소       1
# 4     ynat-v1_train_00007             아가메즈 33득점 우리카드 KB손해보험 완파…3위 굳...       4
# ...                   ...                                          ...     ...
# 1068  ynat-v1_train_02787              13이 노바 라이n2·미J어패0 T3 10 결G상품% *       6
# 1069  ynat-v1_train_02788                           남원소식 춘>X학%단+장Rn 모집       0
# 1070  ynat-v1_train_02789  총리, 세 살 4. 일이 완료되지 않았고, E 작업을 제대로 할 수 없습니다.       2
# 1071  ynat-v1_train_02790            프로농구 개막 ③ 헤인즈의 1만점·양동근의 900스틸…...       3
# 1072  ynat-v1_train_02797             텔레그램+한D 등h亞서 2시간H다운…C버T정gf39종!2보       4
#
# [1073 rows x 3 columns]

# %%
result.to_csv('../../data/preprocessed_v2/Tnoise_comp.csv', index=False)
