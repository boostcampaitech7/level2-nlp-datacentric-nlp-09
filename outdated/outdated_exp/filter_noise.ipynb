# %%
import pandas as pd

raw = pd.read_csv('../../data/raw/train.csv')
df = pd.read_csv('../../data/preprocessed/noise2asterisk.csv')

# '*'/len ratio in text columns
df['noise_ratio'] = df['text'].str.count('\*') / df['text'].str.len()

# sort by noise ratio
df.sort_values(by='noise_ratio', ascending=True, inplace=True)
Lnoise = df.iloc[:1200].copy()
Tnoise = df.iloc[1200:].copy()
Tnoise = Tnoise[Tnoise['noise_ratio'] < 0.5]

Lnoise_id = Lnoise['ID'].to_list()
Tnoise_id = Tnoise['ID'].to_list()

Lnoise_data = raw[raw['ID'].isin(Lnoise_id)].copy()
Tnoise_id_data = raw[raw['ID'].isin(Tnoise_id)].copy()

Tnoise
# Lnoise_data.to_csv('data/preprocessed/asterisk2GTandLnoise.csv', index=False)
# Tnoise_id_data.to_csv('data/preprocessed/asterisk2Tnoise.csv', index=False)
# Out:
#                        ID                                 text  target  \
# 528   ynat-v1_train_00528       *대*령 북핵은*턱밑 비**해결 않으면*한미에 큰 피*       2
# 346   ynat-v1_train_00346       긴급재난지원금 중 기부금은 *천***억원*지급액의 **       2
# 853   ynat-v1_train_00853       ** 더욱 작아지고 간결해진 ** ** 기가지니* 출시       4
# 2612  ynat-v1_train_02612       **텔레콤 ** 드림팀 완성* **리서치센터 조직 신설       4
# 131   ynat-v1_train_00131                    모멘트 학교 급식**칸막이**곡       3
# ...                   ...                                  ...     ...
# 789   ynat-v1_train_00789    중부지방***일*** 장마 오**끝***그치* *푹 찐***       0
# 1884  ynat-v1_train_01884  동*천***서양양** 구간 양*방****일 재난** **간**단       3
# 1899  ynat-v1_train_01899  국민과의*대****통령*최저임**인상***** *축*가*할 길*       2
# 825   ynat-v1_train_00825  *년**북협력기금 *****억 *출*****년보다 ***억 많아       5
# 1260  ynat-v1_train_01260  *란드 총**사*****년 *에 제***집**중도당 참패*합**       6
#
#       noise_ratio
# 528      0.233333
# 346      0.233333
# 853      0.233333
# 2612     0.233333
# ...

# %%
df = pd.read_csv('../../data/preprocessed/recoverTnoise_HighRatioCut.csv')
df_id = df["ID"].tolist()

df2 = pd.read_csv('../../data/preprocessed/asterisk2Tnoise_HighRatioCut.csv')
df2_id = df2["ID"].tolist()

df_id == df2_id
# Out:
# True

# %%
t = df.iloc[1200:].copy()
t['noise_ratio'].plot.hist(bins=10)
t.sort_values(by='noise_ratio', ascending=False, inplace=True)
t_cut = t[t['noise_ratio'] < 0.5]
print(t_cut.shape)
t_cut.head(50)

recovered_all_data = pd.read_csv('../../data/preprocessed/recovered_all_data.csv')
t_cut['recovered'] = recovered_all_data[recovered_all_data['ID'].isin(t_cut['ID'].to_list())]['text']
t_cut.head(50)
# Out:
# (1073, 4)
# /tmp/ipykernel_2167570/1799379087.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t_cut['recovered'] = recovered_all_data[recovered_all_data['ID'].isin(t_cut['ID'].to_list())]['text']
#                        ID                                 text  target  \
# 1260  ynat-v1_train_01260  *란드 총**사*****년 *에 제***집**중도당 참패*합**       6
# 1899  ynat-v1_train_01899  국민과의*대****통령*최저임**인상***** *축*가*할 길*       2
# 1884  ynat-v1_train_01884  동*천***서양양** 구간 양*방****일 재난** **간**단       3
# 825   ynat-v1_train_00825  *년**북협력기금 *****억 *출*****년보다 ***억 많아       5
# 579   ynat-v1_train_00579    *의 *렉시* 혼*에 * ********한 입장 제*해**합       6
# 495   ynat-v1_train_00495    *시티*리버*******확**아스널 **년만에**스리그*좌절       1
# ...

# %%
import pandas as pd

df = pd.read_csv('../data/preprocessed/noise2mask.csv')
df
# Out:
#                        ID                               text  target
# 0     ynat-v1_train_00000   정* *파* 미사* *** 이용기간 ** 단* *분종**보       4
# 1     ynat-v1_train_00001        *찰*국**** 로**한** 회장 * ****송*       3
# 2     ynat-v1_train_00002             * 김정* 자주통일 새***열*나가야*보       2
# 3     ynat-v1_train_00003      갤노트* 주말 **만대 개통*시장은 불법 보조금 얼룩       5
# 4     ynat-v1_train_00004       ***대선*앞두고 ****단 발* *비해 감시 강화       6
# ...                   ...                                ...     ...
# 2795  ynat-v1_train_02795  트럼프 폭스뉴스 앵커들 충성도 점수매겨***점만점에 **점도       6
# 2796  ynat-v1_train_02796        삼성 갤럭시** 정식 출시 첫 주말 이통시장 잠잠       2
# 2797  ynat-v1_train_02797   텔레그램*한* 등**서 *시간*다운**버*정****종**보       4
# 2798  ynat-v1_train_02798    인터뷰 류현진 친구에게 안타 맞는 것 싫어해*승부는 냉정       1
# 2799  ynat-v1_train_02799               지능정보사회 대비 국가 종합대책 마련       4
#
# [2800 rows x 3 columns]

# %%
# '*'/len ratio in text columns
df['noise_ratio'] = df['text'].str.count('\*') / df['text'].str.len()
df
# Out:
#                        ID                               text  target  \
# 0     ynat-v1_train_00000   정* *파* 미사* *** 이용기간 ** 단* *분종**보       4
# 1     ynat-v1_train_00001        *찰*국**** 로**한** 회장 * ****송*       3
# 2     ynat-v1_train_00002             * 김정* 자주통일 새***열*나가야*보       2
# 3     ynat-v1_train_00003      갤노트* 주말 **만대 개통*시장은 불법 보조금 얼룩       5
# 4     ynat-v1_train_00004       ***대선*앞두고 ****단 발* *비해 감시 강화       6
# ...                   ...                                ...     ...
# 2795  ynat-v1_train_02795  트럼프 폭스뉴스 앵커들 충성도 점수매겨***점만점에 **점도       6
# 2796  ynat-v1_train_02796        삼성 갤럭시** 정식 출시 첫 주말 이통시장 잠잠       2
# 2797  ynat-v1_train_02797   텔레그램*한* 등**서 *시간*다운**버*정****종**보       4
# 2798  ynat-v1_train_02798    인터뷰 류현진 친구에게 안타 맞는 것 싫어해*승부는 냉정       1
# 2799  ynat-v1_train_02799               지능정보사회 대비 국가 종합대책 마련       4
#
#       noise_ratio
# 0        0.406250
# 1        0.592593
# 2        0.318182
# 3        0.137931
# 4        0.357143
# ...           ...
# ...

# %%
# sort by noise ratio
df.sort_values(by='noise_ratio', ascending=True, inplace=True)
df
# Out:
#                        ID                                   text  target  \
# 1452  ynat-v1_train_01452                     베르나르 베르베르 방한 기자간담회       1
# 780   ynat-v1_train_00780                 이주열 통화정책 완화정도 추가 조정 필요       0
# 2329  ynat-v1_train_02329             윤상현 오늘 아침 김무성 자택 찾아 사과했다속보       5
# 1206  ynat-v1_train_01206                외교부 송민순 회고록 관련 언급할 사안없어       1
# 1200  ynat-v1_train_01200           게시판 관광공사 대학생 안전여행 슬로건 공모전 개최       0
# ...                   ...                                    ...     ...
# 2528  ynat-v1_train_02528  ********** ***만명** *파****비**개시 *****만       5
# 1612  ynat-v1_train_01612         *** *** ******한 *****솔***검증 **       4
# 133   ynat-v1_train_00133                *씨* *년 *업* ************       5
# 760   ynat-v1_train_00760              *병호*** ********* ***** 연*       1
# 2105  ynat-v1_train_02105       *****홀*****년***요*서트****세********       0
#
#       noise_ratio
# 1452     0.000000
# 780      0.000000
# 2329     0.000000
# ...

# %%
df_1 = df.iloc[:1120].copy()
df_2 = df.head(1120).copy()

(df_1.equals(df_2))
# Out:
# True

# %%
df_1
# Out:
#                        ID                           text  target  noise_ratio
# 1452  ynat-v1_train_01452             베르나르 베르베르 방한 기자간담회       1     0.000000
# 780   ynat-v1_train_00780         이주열 통화정책 완화정도 추가 조정 필요       0     0.000000
# 2329  ynat-v1_train_02329     윤상현 오늘 아침 김무성 자택 찾아 사과했다속보       5     0.000000
# 1206  ynat-v1_train_01206        외교부 송민순 회고록 관련 언급할 사안없어       1     0.000000
# 1200  ynat-v1_train_01200   게시판 관광공사 대학생 안전여행 슬로건 공모전 개최       0     0.000000
# ...                   ...                            ...     ...          ...
# 1649  ynat-v1_train_01649  베스트셀러 김난도 트렌드 코리아 **** *주째 *위       3     0.206897
# 2161  ynat-v1_train_02161  추억의 노키아폰 부활***유로 헐값***시간 통화종합       5     0.206897
# 534   ynat-v1_train_00534  국토* 공동주택 관리 *우수*지에*서울 텐*힐 *단지       5     0.206897
# 431   ynat-v1_train_00431  **** 프로야구 앱 출시 사흘 만에 **만 다운로드       3     0.206897
# 153   ynat-v1_train_00153       힐만 감독 산체스 *****일 불펜에서 대기       6     0.208333
#
# [1120 rows x 4 columns]

# %%
df_2
# Out:
#                        ID                           text  target  noise_ratio
# 1452  ynat-v1_train_01452             베르나르 베르베르 방한 기자간담회       1     0.000000
# 780   ynat-v1_train_00780         이주열 통화정책 완화정도 추가 조정 필요       0     0.000000
# 2329  ynat-v1_train_02329     윤상현 오늘 아침 김무성 자택 찾아 사과했다속보       5     0.000000
# 1206  ynat-v1_train_01206        외교부 송민순 회고록 관련 언급할 사안없어       1     0.000000
# 1200  ynat-v1_train_01200   게시판 관광공사 대학생 안전여행 슬로건 공모전 개최       0     0.000000
# ...                   ...                            ...     ...          ...
# 1649  ynat-v1_train_01649  베스트셀러 김난도 트렌드 코리아 **** *주째 *위       3     0.206897
# 2161  ynat-v1_train_02161  추억의 노키아폰 부활***유로 헐값***시간 통화종합       5     0.206897
# 534   ynat-v1_train_00534  국토* 공동주택 관리 *우수*지에*서울 텐*힐 *단지       5     0.206897
# 431   ynat-v1_train_00431  **** 프로야구 앱 출시 사흘 만에 **만 다운로드       3     0.206897
# 153   ynat-v1_train_00153       힐만 감독 산체스 *****일 불펜에서 대기       6     0.208333
#
# [1120 rows x 4 columns]

# %%
df_filtered = df.iloc[:1120].copy()
df_remaining = df.iloc[1120:].copy()
df_filtered.shape, df_remaining.shape, df.shape
# Out:
# ((1120, 4), (1680, 4), (2800, 4))

# %%
# drop noise_ratio column
df_filtered.drop(columns=['noise_ratio'], inplace=True)
df_filtered
# Out:
#                        ID                           text  target
# 1452  ynat-v1_train_01452             베르나르 베르베르 방한 기자간담회       1
# 780   ynat-v1_train_00780         이주열 통화정책 완화정도 추가 조정 필요       0
# 2329  ynat-v1_train_02329     윤상현 오늘 아침 김무성 자택 찾아 사과했다속보       5
# 1206  ynat-v1_train_01206        외교부 송민순 회고록 관련 언급할 사안없어       1
# 1200  ynat-v1_train_01200   게시판 관광공사 대학생 안전여행 슬로건 공모전 개최       0
# ...                   ...                            ...     ...
# 1649  ynat-v1_train_01649  베스트셀러 김난도 트렌드 코리아 **** *주째 *위       3
# 2161  ynat-v1_train_02161  추억의 노키아폰 부활***유로 헐값***시간 통화종합       5
# 534   ynat-v1_train_00534  국토* 공동주택 관리 *우수*지에*서울 텐*힐 *단지       5
# 431   ynat-v1_train_00431  **** 프로야구 앱 출시 사흘 만에 **만 다운로드       3
# 153   ynat-v1_train_00153       힐만 감독 산체스 *****일 불펜에서 대기       6
#
# [1120 rows x 3 columns]

# %%
df_filtered.head(5)
# Out:
#                        ID                          text  target  noise_ratio
# 1452  ynat-v1_train_01452            베르나르 베르베르 방한 기자간담회       1          0.0
# 780   ynat-v1_train_00780        이주열 통화정책 완화정도 추가 조정 필요       0          0.0
# 2329  ynat-v1_train_02329    윤상현 오늘 아침 김무성 자택 찾아 사과했다속보       5          0.0
# 1206  ynat-v1_train_01206       외교부 송민순 회고록 관련 언급할 사안없어       1          0.0
# 1200  ynat-v1_train_01200  게시판 관광공사 대학생 안전여행 슬로건 공모전 개최       0          0.0

# %%
df_filtered = df.head(1120).copy()
# df_filtered.sort_values(by='noise_ratio', ascending=True, inplace=True)
df_filtered.head(5)
# Out:
#                        ID                          text  target  noise_ratio
# 1452  ynat-v1_train_01452            베르나르 베르베르 방한 기자간담회       1          0.0
# 780   ynat-v1_train_00780        이주열 통화정책 완화정도 추가 조정 필요       0          0.0
# 2329  ynat-v1_train_02329    윤상현 오늘 아침 김무성 자택 찾아 사과했다속보       5          0.0
# 1206  ynat-v1_train_01206       외교부 송민순 회고록 관련 언급할 사안없어       1          0.0
# 1200  ynat-v1_train_01200  게시판 관광공사 대학생 안전여행 슬로건 공모전 개최       0          0.0

# %%
df_filtered2 = pd.read_csv('../data/preprocessed/mask2goldentruth.csv')
df_filtered2.head(5)
# Out:
#                     ID                             text  target  noise_ratio
# 0  ynat-v1_train_02520    잠금화면 플랫폼 버즈빌 인도 잠금화면앱 슬라이드 인수       6          0.0
# 1  ynat-v1_train_02276                이공대 내부 살펴보는 홍콩 경찰       3          0.0
# 2  ynat-v1_train_00519  서울 초등학생 새학기부터 구강검진 결과 스마트폰으로 확인       1          0.0
# 3  ynat-v1_train_02121         예멘 반군 사우디 석유시설 여전히 공격 목표       6          0.0
# 4  ynat-v1_train_02123         베스트셀러 소셜미디어 입소문 탄 에세이 인기       5          0.0
