# %%
import pandas as pd

raw = pd.read_csv('../../data/preprocessed_v2/Lnoise_recover_1200_v1.csv')
mecab = pd.read_csv('../../data/preprocessed_v2/Lnoise_recover_mecab_1200.csv')

# %%
cnt = 0
for i in range(len(raw)):
    if raw['target'][i] != mecab['target'][i]:
        print(raw['ID'][i])
        print(raw['text'][i])
        print(raw['target'][i])
        print(mecab['target'][i])
        print()
        cnt += 1
print(cnt)
# Out:
# ynat-v1_train_00030
# 해외로밍 m금폭탄 n동차단 더 빨$진다
# 5
# 4
#
# ynat-v1_train_00034
# 안보리 대북결의안 2270호 이행보고서 제출한 나라 70개 육박
# 2
# 6
#
# ynat-v1_train_00043
# 한국민족의 뿌리가 북방…5천년 전 한반도서 자생적으로 형성
# 0
# 2
#
# ynat-v1_train_00071
# 영상 냄새가 나는데…퇴근길 마주친 수상한 차 따라가봤더니
# 0
# 3
#
# ynat-v1_train_00090
# 서울문고 N풍그U에 인수… f라인서점 교m영풍y양강d도로
# 4
# 0
#
# ynat-v1_train_00093
# 문대통령 호주 총리와 축구 평가전 1대1 무승부 축하
# 2
# 1
#
# ynat-v1_train_00100
# 北 서방에 백두산 연구 먼저 제의…과학외교 활발
# 2
# 4
#
# ynat-v1_train_00101
# ~학농구리- 8일 고려대중앙대 경pt 개막
# 1
# 3
#
# ynat-v1_train_00118
# 러 우주로켓 벼락 맞고도 멀쩡…탑재 위성 정상궤도 올려
# 6
# 4
#
# ynat-v1_train_00164
# 日도쿄 주택가 공원 연못서 토막시신 발견
# 3
# 0
#
# ynat-v1_train_00173
# 홍남기 미래부 1차관 서울혁신센터 등 방문
# 4
# 2
#
# ynat-v1_train_00175
# 북한 사이버 공격 집단 세계 은행들 상대 1천억 탈취종합
# 3
# 6
#
# ynat-v1_train_00205
# 특징주 ;면분할 F성전자v귀환S첫날X약세
# 5
# 4
#
# ynat-v1_train_00212
# 장애인 정책 발표하는 안철수
# 3
# 2
#
# ynat-v1_train_00223
# 카카오미니 예판 38분 만에 마감…접속 몰려 에러 속출
# 1
# 4
#
# ynat-v1_train_00235
# 신간 답이 보이지 않는 상황을 견디는 힘
# 0
# 3
#
# ...
