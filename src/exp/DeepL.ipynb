# %%
import pandas as pd

df = pd.read_csv('../../data/raw/train.csv')
df
# Out:
#                        ID                               text  target
# 0     ynat-v1_train_00000   정i :파1 미사z KT( 이용기간 2e 단] Q분종U2보       4
# 1     ynat-v1_train_00001        K찰.국DLwo 로L3한N% 회장 2 T0&}송=       3
# 2     ynat-v1_train_00002             m 김정) 자주통일 새,?r열1나가야1보       2
# 3     ynat-v1_train_00003      갤노트8 주말 27만대 개통…시장은 불법 보조금 얼룩       5
# 4     ynat-v1_train_00004       pI美대선I앞두고 R2fr단 발] $비해 감시 강화       6
# ...                   ...                                ...     ...
# 2795  ynat-v1_train_02795  트럼프 폭스뉴스 앵커들 충성도 점수매겨…10점만점에 12점도       6
# 2796  ynat-v1_train_02796        삼성 갤럭시S9 정식 출시 첫 주말 이통시장 잠잠       2
# 2797  ynat-v1_train_02797   텔레그램+한D 등h亞서 2시간H다운…C버T정gf39종!2보       4
# 2798  ynat-v1_train_02798    인터뷰 류현진 친구에게 안타 맞는 것 싫어해…승부는 냉정       1
# 2799  ynat-v1_train_02799               지능정보사회 대비 국가 종합대책 마련       4
#
# [2800 rows x 3 columns]

# %%
import pandas as pd
import deepl
from googletrans import Translator
from tqdm import tqdm


def back_translate_deepl(text):
    result = translator_deepl.translate_text(text, target_lang="EN-US")
    if not result.text:
        return None
    result = translator_deepl.translate_text(result.text, target_lang="KO")
    return result.text

def back_translate_google(text, src="ko", dest="en"):
    while True:
        try:
            en_result = translator_google.translate(text, dest=dest)
            ko_result = translator_google.translate(en_result.text, dest=src)
            result = ko_result.text
            return result
        except Exception as e:
            time.sleep(1)


auth_key = "79c79fb2-eba6-42b4-a677-799cf2843151:fx"
translator_deepl = deepl.Translator(auth_key)
# translator_google = Translator()

tqdm.pandas()

noise_Tnoise_HighRatioCut = pd.read_csv('../../data/preprocessed/asterisk2Tnoise_HighRatioCut.csv')

noise_Tnoise_HighRatioCut['text'] = noise_Tnoise_HighRatioCut['text'].progress_apply(back_translate_deepl)
# df['google'] = df['text'].progress_apply(back_translate_google)

# save
noise_Tnoise_HighRatioCut.to_csv('../../data/preprocessed/noise2translated_Tnoise_HighRatioCut_1073.csv', index=False)
# Out:
# 100%|██████████| 1/1 [00:03<00:00,  3.02s/it]

# %%
noise_Tnoise_HighRatioCut = pd.read_csv('../../data/preprocessed/asterisk2Tnoise_HighRatioCut.csv')
noise_Tnoise_HighRatioCut
text = noise_Tnoise_HighRatioCut['text'].tolist()
text

# sum text length
length = 0
for i in text:
    length += len(i)
length
# Out:
# 29514

# %%
import pandas as pd
import deepl
from googletrans import Translator
from tqdm import tqdm


def back_translate_deepl(text):
    result = translator_deepl.translate_text(text, target_lang="EN-US")
    if not result.text:
        return None
    result = translator_deepl.translate_text(result.text, target_lang="KO")
    return result.text

def back_translate_google(text, src="ko", dest="en"):
    while True:
        try:
            en_result = translator_google.translate(text, dest=dest)
            ko_result = translator_google.translate(en_result.text, dest=src)
            result = ko_result.text
            return result
        except Exception as e:
            time.sleep(1)


auth_key = "79c79fb2-eba6-42b4-a677-799cf2843151:fx"
translator_deepl = deepl.Translator(auth_key)

translator_google = Translator()

tqdm.pandas()

df = pd.read_csv('../../data/raw/train.csv').head(20)

df['deepL'] = df['text'].progress_apply(back_translate_deepl)
df['google'] = df['text'].progress_apply(back_translate_google)

df
# Out:
# 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# 100%|██████████| 20/20 [00:16<00:00,  1.24it/s]
#                      ID                              text  target  \
# 0   ynat-v1_train_00000  정i :파1 미사z KT( 이용기간 2e 단] Q분종U2보       4
# 1   ynat-v1_train_00001       K찰.국DLwo 로L3한N% 회장 2 T0&}송=       3
# 2   ynat-v1_train_00002            m 김정) 자주통일 새,?r열1나가야1보       2
# 3   ynat-v1_train_00003     갤노트8 주말 27만대 개통…시장은 불법 보조금 얼룩       5
# 4   ynat-v1_train_00004      pI美대선I앞두고 R2fr단 발] $비해 감시 강화       6
# 5   ynat-v1_train_00005    美성인 6명 중 1명꼴 배우자·연인 빚 떠안은 적 있다       0
# 6   ynat-v1_train_00006             프로야구~롯TKIAs광주 경기 y천취소       1
# 7   ynat-v1_train_00007  아가메즈 33득점 우리카드 KB손해보험 완파…3위 굳...       4
# 8   ynat-v1_train_00008    朴대통령 얼마나 많이 놀라셨어요…경주 지진현장 방문종합       6
# 9   ynat-v1_train_00009        듀얼심 아이폰 하반기 출시설 솔솔…알뜰폰 기대감       4
# 10  ynat-v1_train_00010       oi 매력 R모h츠a열#w3약 >l·주가 고Q/진       5
# 11  ynat-v1_train_00011              NH투자 1월 옵션 만기일 매도 우세       1
# 12  ynat-v1_train_00012          황총리 각 부처 비상대비태세 철저히 강구해야       2
# 13  ynat-v1_train_00013      아이`XSI수리0* b대`…맥3 디dF레< 41/'       4
# 14  ynat-v1_train_00014      문/인 당2 4nS 민관2동7사위 /"X보 철거tt       2
# 15  ynat-v1_train_00015    게시판 KISA 박민정 책임연구원 APTLD 이사 선출       0
# 16  ynat-v1_train_00016    공사업체 협박에 분쟁해결 명목 돈 받은 언론인 집행유예       3
# 17  ynat-v1_train_00017      월세 전환에 늘어나는 주거비 부담…작년 역대 최고치       5
# 18  ynat-v1_train_00018                      개R전 연w정연H 작가       0
# 19  ynat-v1_train_00019      페이스북 인터넷 드론 아퀼라 실물 첫 시험비행 성공       2
#
#                                         deepL  \
# 0            정i :파1 미사z KT( 이용기간 2e 단] Q분종U2보
# 1         Kchal.gookDLwo 로L3hanN% 회장 2 T0&}송=
# 2              M 김정은) 빈번한 통일 새,?r 행 1 나가야 1 보
# 3       갤럭시노트8, 주말 동안 27만대 판매...시장, 불법 보조금 난무
# 4             pIUS 대통령 선거II강화 R2frDan] $위반 감시
# 5   미국 성인 6명 중 1명은 배우자 또는 연인에게 빚을 진 경험이 있습니다.
# 6                     KBO~롯데 자이언츠 광주 경기 예천 취소
# 7        Agamez 33득점 우리카드 kb손해보험 완파...3위 굳...
# 8            朴大통령 얼마나 많이 놀라셨어요...경주 지진현장 방문종합
# 9         듀얼심 아이폰 하반기 출시 루머... 저렴한 휴대폰에 대한 기대
# 10          오이 매력 알모사 히트#w3about >l-스톡 하이 Q/진
# 11                 NH 인베스트먼트 1월 옵션 만기, 매도자 우세
# 12         총리는 각 부처에 비상 사태에 철저히 대비할 것을 촉구합니다.
# 13              i`XSI수리0* b대`...맥3 디dF레< 41/'
# 14       2 4nS 민간인 2 청동 7 주사위/문/인당 /"X 빔 철거 t
# 15           게시판 KISA 박민정 원장, APTLD 이사회 멤버 선출
# 16     계약업체 협박으로 분쟁 해결을 위해 돈을 받은 기자에게 집행유예 선고
# 17    월세에서 자가 전환으로 주거비 부담 증가... 지난해 사상 최고치 기록
# 18                                 개전 전정연H 저자
# 19           페이스북의 인터넷 드론 아퀼라, 처녀 시험 비행에 성공하다
#
#                                                google
# 0                                   정 I : 파 1 질량 z Kt
# 1             K. Kuk, DLWO, L3 HAN N% 회장 2 T0 &} 노래 =
# 2                                                 m 킴
# 3                  270,000 갤럭시 노트 8 주… 시장은 불법 보조금입니다.
# 4                  Pi 미국 대통령 선거 I의 앞에있는 $ r2fr에 비해 강화
# 5               6 명의 미국 성인 중 1 명은 배우자와 연인의 빚을지고 있습니다.
# 6                 프로 야구 ~ 로트 tkias gwangju gyeonggi y
# 7         Agamez 33 포인트 Woori 카드 KB 보험 WANPA… 3 위 ...
# 8        대통령은 얼마입니까? Gyongju Earthquake를 포괄적으로 방문했습니다
# 9                         듀얼 Simsim iPhone Solsol… 기대
# 10             OI Charm r mo h ts 열#W3 약점> l/주가 Q/Jin
# 11                                   NH 투자 1 월 선택적 판매
# 12                          황 왕 총리는 철저하게 철저하게 주어져야한다.
# 13             어린이 'XSI 수리 0* B 대'… MAC 3 DF LE <41/'
# 14  GATE /DANG 2 4NS PUBLIC -PRIVATE 2 -DONG 7 SON...
# 15  Bulletin Board Kisa Park Min -Jung, 선임 연구원 Apt...
# 16                건설 회사의 위협에 대한 분쟁으로 지명 된 언론인의 실행자 실행
# 17                         주택 비용은 월 임대료 전환의 증가… 작년 최고
# 18                   Dog R Jeon Yeon H Jeongyeon H 작가
# 19      Facebook Internet Drone Aquila의 첫 번째 시험 비행 성공

# %%
mecab = pd.read_csv('../../data/exp/train_noise_v3.csv').head(20)
mecab['deepL'] = mecab['text'].progress_apply(back_translate_deepl)
mecab['google'] = mecab['text'].progress_apply(back_translate_google)
mecab
# Out:
# 100%|██████████| 20/20 [00:19<00:00,  1.01it/s]
# 100%|██████████| 20/20 [00:44<00:00,  2.24s/it]
#                      ID                 text  target                   deepL  \
# 0   ynat-v1_train_00000  정 파 미사 이용 기간 단 분종 보       4        정통 미사 사용 기간 단분종보
# 1   ynat-v1_train_00001             찰 국 회장 송       3               찰스 국 송 회장
# 2   ynat-v1_train_00002            김정 통일 새 보       2              김정은의 새 보고서
# 3   ynat-v1_train_00004         美 대선 발 감시 강화       6  미국 대통령 선거를 위한 도보 감시 강화
# 4   ynat-v1_train_00006   프로 야구 롯 광주 경기 천취 소       1         프로야구장 광주 경기 천퀴쇼
# 5   ynat-v1_train_00010        매력 모 츠 약 주가 진       5               참 모츠 야쿠주진
# 6   ynat-v1_train_00013          아이 수리 대 맥 디       4           안과 수술 vs 맥도날드
# 7   ynat-v1_train_00014      문 인 민관 동 위 보 철거       2    문인-시민 커뮤니티 건물의 거더 철거
# 8   ynat-v1_train_00018          개 전 연 정연 작가       0                 정연정, 작가
# 9   ynat-v1_train_00021        수단 팬 호 족 한마 최       1             최한마, 판호, 수단
# 10  ynat-v1_train_00022               차 임원 보       3                    부행정관
# 11  ynat-v1_train_00025             선 폭 현장 조       3              선 너비 필드 퍼즐
# 12  ynat-v1_train_00026          콤 분기 영 익 증가       5                조합 수익 증대
# 13  ynat-v1_train_00027             생 인증 유 끝       4                생체 인증 종료
# 14  ynat-v1_train_00028        강 감독 축구 연맹 회부       1    강 코치는 축구 연맹을 언급했습니다.
# 15  ynat-v1_train_00029          축구 인천 운 드 영       1             축구 인천 유나이티드
# 16  ynat-v1_train_00031       세계 무역 협회 무역 배출       3         세계 무역 협회 무역 배출량
# 17  ynat-v1_train_00032    박 항 매직 베트남 축구 표 팀       1       박항 매직 베트남 축구 티켓 팀
# 18  ynat-v1_train_00033         학 석면 거 규정 지키       3                석면 규정 준수
# 19  ynat-v1_train_00037           생산 인공광 활 적       4           프로덕션 인공 조명 활동
#
#                          google
# 0              Jeongpa 대량 사용 기간
# 1                         회장 노래
# 2   Kim Jong Unification New Bo
# 3                미국 대통령 모니터링 강화
# 4       프로 야구장 Gwangju Gyeonggi
# 5                          매력적인
# 6                   아동 수리 대 맥 d
# 7                            철거
# 8                     정기 연이 -안연
# 9                수단 팬 호수 한 마초 i
# 10            Cha Executive Boy
# 11                    태양 너비 사이트
# 12              COM 찐 정신이 증가합니다
# 13                    태어난 인증의 끝
# 14                   강 감독 축구 연맹
# 15              축구 인천 und Young
# 16               세계 무역 협회 무역 배출
# 17             파크 행 마법 베트남 축구 팀
# 18                   석면을 유지하십시오
# 19                   생산 인공 태양 광

# %%
asterisk = pd.read_csv('../../data/preprocessed/noise2asterisk.csv').head(20)
asterisk['deepL'] = asterisk['text'].progress_apply(back_translate_deepl)
asterisk['google'] = asterisk['text'].progress_apply(back_translate_google)
asterisk
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# 100%|██████████| 20/20 [00:16<00:00,  1.23it/s]
# 100%|██████████| 20/20 [00:41<00:00,  2.08s/it]
#                      ID                              text  target  \
# 0   ynat-v1_train_00000  정* *파* 미사* *** 이용기간 ** 단* *분종**보       4
# 1   ynat-v1_train_00001       *찰*국**** 로**한** 회장 * ****송*       3
# 2   ynat-v1_train_00002            * 김정* 자주통일 새***열*나가야*보       2
# 3   ynat-v1_train_00003     갤노트* 주말 **만대 개통*시장은 불법 보조금 얼룩       5
# 4   ynat-v1_train_00004      ***대선*앞두고 ****단 발* *비해 감시 강화       6
# 5   ynat-v1_train_00005    *성인 *명 중 *명꼴 배우자*연인 빚 떠안은 적 있다       0
# 6   ynat-v1_train_00006             프로야구*롯*****광주 경기 *천취소       1
# 7   ynat-v1_train_00007  아가메즈 **득점 우리카드 **손해보험 완파**위 굳***       4
# 8   ynat-v1_train_00008    *대통령 얼마나 많이 놀라셨어요*경주 지진현장 방문종합       6
# 9   ynat-v1_train_00009        듀얼심 아이폰 하반기 출시설 솔솔*알뜰폰 기대감       4
# 10  ynat-v1_train_00010       ** 매력 *모*츠*열***약 ***주가 고**진       5
# 11  ynat-v1_train_00011              **투자 *월 옵션 만기일 매도 우세       1
# 12  ynat-v1_train_00012          황총리 각 부처 비상대비태세 철저히 강구해야       2
# 13  ynat-v1_train_00013      아이****수리** *대**맥* 디**레* ****       4
# 14  ynat-v1_train_00014      문*인 당* *** 민관*동*사위 ***보 철거**       2
# 15  ynat-v1_train_00015    게시판 **** 박민정 책임연구원 ***** 이사 선출       0
# 16  ynat-v1_train_00016    공사업체 협박에 분쟁해결 명목 돈 받은 언론인 집행유예       3
# 17  ynat-v1_train_00017      월세 전환에 늘어나는 주거비 부담*작년 역대 최고치       5
# 18  ynat-v1_train_00018                      개*전 연*정연* 작가       0
# 19  ynat-v1_train_00019      페이스북 인터넷 드론 아퀼라 실물 첫 시험비행 성공       2
#
#                                             deepL  \
# 0                일반* *파* 매스* ***사용기간** 전용* *분종**보
# 1                회장 *찰*국**** by *한*한* * ****Song*
# 2                                            None
# 3        갤럭시 노트* 주말 **10,000대 판매* 불법 보조금으로 오염된 시장
# 4                  대통령 선거를 앞두고 감시 강화, **** 단계적 강화
# 5            *성인 1명 중 1명은 배우자 또는 배우자가 빚을 지고 있습니다.
# 6                           프로야구*롯*****광주 경기 *천취소
# 7                     아가메즈 **점수 우리카드 **보험 **승***.
# 8                  *대통령은 얼마나 겁먹었나*경주 지진 현장 방문 총정리
# 9                      듀얼심 아이폰 하반기 출시설 솔솔*앨범폰 기대감
# 10                 ** 매력적인 *동기부여*** 정보*** 핫*** 주식
# 11                            **투자 *월 옵션 만기 매도 우위
# 12             총리는 각 부처에 비상 사태에 철저히 대비할 것을 촉구합니다.
# 13                      i****suri** *대맥* 데레* ****
# 14              문*당*사람* ***공공*민간*부서** ***빔 철거****
# 15                      게시판 **** 박민정 ***** 이사진 선출
# 16         계약업체 협박으로 분쟁 해결을 위해 돈을 받은 기자에게 집행유예 선고
# 17  임대료에서 소유로의 전환*으로 인한 주거비 부담 증가* 최근 1년 사이 가장 높음
# 18                                            작성자
# 19               페이스북의 인터넷 드론 아퀼라, 처녀 시험 비행에 성공하다
#
#                                                google
# 0    Jeong ** Pa*Mass **** 사용 날짜 ** Dan ** Bonjong **
# 1                            *회장 ** 한 ** 회장 ***** 노래*
# 2                        *Kim Jong*자주 통합 된 새로운 *** 행*
# 3                갤럭시 노트*주말 ** 10,000 단위*시장은 불법 보조금입니다
# 4             *** 대통령 선거*단일 발에 비해 **** 강화 모니터링에 앞서 **
# 5                             *성인 *중 하나 *myeong -jae.
# 6                    프로 야구*로트 ***** gwangju gyeonggi*
# 7                   agamez ** 득점 woori 카드 ** wanpa **
# 8              *Gyongju 지진 현장 방문이 포괄적 인 대통령이 얼마나 놀랐는지
# 9                 듀얼 Simsim iPhone은 Solsol*기대를 기대했습니다
# 10                     ** Charm*mo*tsu*row *** *** 주식
# 11                                   ** 투자 *월간 선택적 판매
# 12                          황 왕 총리는 철저하게 철저하게 주어져야한다.
# 13                         i **** 수리 ** Mac*D ** ****
# 14                                                 큐.
# 15  Bulletin Board **** Park Min -Jung 연구원 ***** 선...
# 16                건설 회사의 위협에 대한 분쟁으로 지명 된 언론인의 실행자 실행
# 17                         월 임대료 전환이 증가하는 주택 비용*작년 최고
# 18                                         개*전이*정수*작가
# 19      Facebook Internet Drone Aquila의 첫 번째 시험 비행 성공
